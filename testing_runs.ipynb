# %%
from importlib import reload
import torch

import testing

from models.ffnet import FFNet
from models.mlp import MLP
from models.siren import SIREN
from models.ffnet2 import FFNet2
from models.mfn import GaborNetwork
from models.gaussian import Gaussian
from models.mixed import AlternatingModel
# Out:
# torch.Size([16, 128, 3])
# torch.Size([16, 128, 1])

# %%
reload(testing)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [128],
    'hidden_layers': [3],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [1000],
}
#normal testing
#testing with only some nonzero values
#testing with nonzero values picked each number of steps

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True],'first_omega_zero':[100],'hidden_omega_zero':[45]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008264
# Step: 200, Test MSE: 0.006518
# Step: 300, Test MSE: 0.005752
# Step: 400, Test MSE: 0.005557
# Step: 500, Test MSE: 0.005479
# Step: 600, Test MSE: 0.005173
# Step: 700, Test MSE: 0.005111
# Step: 800, Test MSE: 0.005008
# Step: 900, Test MSE: 0.005138
# Step: 1000, Test MSE: 0.005048
# MSE (original scale): 323.28910564131525
# MSE (transformed scale): 0.005048168823122978
# Compression Ratio: 22.721758502896183
# Training time: 10.63741135597229
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005600
# Step: 200, Test MSE: 0.004316
# Step: 300, Test MSE: 0.004230
# Step: 400, Test MSE: 0.004006
# Step: 500, Test MSE: 0.003944
# Step: 600, Test MSE: 0.003827
# Step: 700, Test MSE: 0.003822
# Step: 800, Test MSE: 0.003736
# Step: 900, Test MSE: 0.003742
# Step: 1000, Test MSE: 0.003654
# MSE (original scale): 262.3269745649264
# MSE (transformed scale): 0.0036539153661578894
# Compression Ratio: 22.721758502896183
# Training time: 10.12750506401062
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.006300
# Step: 200, Test MSE: 0.005216
# Step: 300, Test MSE: 0.004910
# Step: 400, Test MSE: 0.004802
# Step: 500, Test MSE: 0.004695
# Step: 600, Test MSE: 0.004664
# Step: 700, Test MSE: 0.004541
# Step: 800, Test MSE: 0.004560
# Step: 900, Test MSE: 0.004640
# Step: 1000, Test MSE: 0.004569
# MSE (original scale): 259.9207389453648
# MSE (transformed scale): 0.004568659700453281
# Compression Ratio: 22.721758502896183
# Training time: 10.132577657699585
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009445
# Step: 200, Test MSE: 0.007692
# Step: 300, Test MSE: 0.007332
# Step: 400, Test MSE: 0.007050
# Step: 500, Test MSE: 0.007255
# Step: 600, Test MSE: 0.006953
# Step: 700, Test MSE: 0.006881
# Step: 800, Test MSE: 0.006798
# Step: 900, Test MSE: 0.006764
# Step: 1000, Test MSE: 0.006800
# MSE (original scale): 409.5388324129853
# MSE (transformed scale): 0.0068002925254404545
# Compression Ratio: 22.721758502896183
# Training time: 10.130965232849121
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005313
# Step: 200, Test MSE: 0.004296
# Step: 300, Test MSE: 0.004092
# Step: 400, Test MSE: 0.003930
# Step: 500, Test MSE: 0.003884
# Step: 600, Test MSE: 0.003735
# Step: 700, Test MSE: 0.003782
# Step: 800, Test MSE: 0.003693
# Step: 900, Test MSE: 0.003620
# Step: 1000, Test MSE: 0.003628
# MSE (original scale): 275.4036353748327
# MSE (transformed scale): 0.0036279663909226656
# Compression Ratio: 22.721758502896183
# Training time: 10.127034902572632
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.006434
# Step: 200, Test MSE: 0.005009
# Step: 300, Test MSE: 0.004647
# Step: 400, Test MSE: 0.004616
# Step: 500, Test MSE: 0.004413
# Step: 600, Test MSE: 0.004256
# Step: 700, Test MSE: 0.004214
# Step: 800, Test MSE: 0.004186
# Step: 900, Test MSE: 0.004164
# Step: 1000, Test MSE: 0.004126
# MSE (original scale): 248.15906072205487
# MSE (transformed scale): 0.00412596482783556
# Compression Ratio: 22.721758502896183
# Training time: 10.136204242706299
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.007681
# Step: 200, Test MSE: 0.006622
# Step: 300, Test MSE: 0.006113
# Step: 400, Test MSE: 0.006054
# Step: 500, Test MSE: 0.005906
# Step: 600, Test MSE: 0.005972
# Step: 700, Test MSE: 0.005936
# Step: 800, Test MSE: 0.005745
# Step: 900, Test MSE: 0.005780
# Step: 1000, Test MSE: 0.005736
# MSE (original scale): 332.1362533467202
# MSE (transformed scale): 0.005735563114285469
# Compression Ratio: 22.721758502896183
# Training time: 10.125061273574829
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005794
# Step: 200, Test MSE: 0.004711
# Step: 300, Test MSE: 0.004251
# Step: 400, Test MSE: 0.004175
# Step: 500, Test MSE: 0.004027
# Step: 600, Test MSE: 0.004060
# Step: 700, Test MSE: 0.003958
# Step: 800, Test MSE: 0.003982
# Step: 900, Test MSE: 0.003894
# Step: 1000, Test MSE: 0.003858
# MSE (original scale): 274.94399734354084
# MSE (transformed scale): 0.0038580019026994705
# Compression Ratio: 22.721758502896183
# Training time: 10.129194498062134
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008150
# Step: 200, Test MSE: 0.006639
# Step: 300, Test MSE: 0.006205
# Step: 400, Test MSE: 0.005953
# Step: 500, Test MSE: 0.005798
# Step: 600, Test MSE: 0.005719
# Step: 700, Test MSE: 0.005508
# Step: 800, Test MSE: 0.005766
# Step: 900, Test MSE: 0.005375
# Step: 1000, Test MSE: 0.005395
# MSE (original scale): 344.3243703982597
# MSE (transformed scale): 0.00539500592276454
# Compression Ratio: 22.721758502896183
# Training time: 10.12446665763855
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.007903
# Step: 200, Test MSE: 0.006498
# Step: 300, Test MSE: 0.006341
# Step: 400, Test MSE: 0.005937
# Step: 500, Test MSE: 0.005946
# Step: 600, Test MSE: 0.005594
# Step: 700, Test MSE: 0.005691
# Step: 800, Test MSE: 0.005816
# Step: 900, Test MSE: 0.005496
# Step: 1000, Test MSE: 0.005414
# MSE (original scale): 332.1268799154953
# MSE (transformed scale): 0.0054139643907547
# Compression Ratio: 22.721758502896183
# Training time: 10.124294519424438
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008653
# Step: 200, Test MSE: 0.007014
# Step: 300, Test MSE: 0.006300
# Step: 400, Test MSE: 0.005911
# Step: 500, Test MSE: 0.005790
# Step: 600, Test MSE: 0.005664
# Step: 700, Test MSE: 0.005643
# Step: 800, Test MSE: 0.005600
# Step: 900, Test MSE: 0.005526
# Step: 1000, Test MSE: 0.005555
# MSE (original scale): 356.63263209086347
# MSE (transformed scale): 0.005554759409278631
# Compression Ratio: 22.721758502896183
# Training time: 10.128139972686768
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010186
# Step: 200, Test MSE: 0.008805
# Step: 300, Test MSE: 0.008049
# Step: 400, Test MSE: 0.007752
# Step: 500, Test MSE: 0.007845
# Step: 600, Test MSE: 0.007697
# Step: 700, Test MSE: 0.007928
# Step: 800, Test MSE: 0.007556
# Step: 900, Test MSE: 0.007624
# Step: 1000, Test MSE: 0.007476
# MSE (original scale): 480.21841532797856
# MSE (transformed scale): 0.007475799415260553
# Compression Ratio: 22.721758502896183
# Training time: 10.128517150878906
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005505
# Step: 200, Test MSE: 0.004457
# Step: 300, Test MSE: 0.004063
# Step: 400, Test MSE: 0.004013
# Step: 500, Test MSE: 0.003871
# Step: 600, Test MSE: 0.003726
# Step: 700, Test MSE: 0.003655
# Step: 800, Test MSE: 0.003654
# Step: 900, Test MSE: 0.003643
# Step: 1000, Test MSE: 0.003607
# MSE (original scale): 270.734007645164
# MSE (transformed scale): 0.00360711757093668
# Compression Ratio: 22.721758502896183
# Training time: 10.125756740570068
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009159
# Step: 200, Test MSE: 0.007887
# Step: 300, Test MSE: 0.007641
# Step: 400, Test MSE: 0.007607
# Step: 500, Test MSE: 0.007779
# Step: 600, Test MSE: 0.007379
# Step: 700, Test MSE: 0.007469
# Step: 800, Test MSE: 0.007470
# Step: 900, Test MSE: 0.007295
# Step: 1000, Test MSE: 0.007257
# MSE (original scale): 440.30352137717534
# MSE (transformed scale): 0.007256895769387484
# Compression Ratio: 22.721758502896183
# Training time: 10.125563621520996
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005623
# Step: 200, Test MSE: 0.004521
# Step: 300, Test MSE: 0.004334
# Step: 400, Test MSE: 0.004091
# Step: 500, Test MSE: 0.003854
# Step: 600, Test MSE: 0.003933
# Step: 700, Test MSE: 0.003817
# Step: 800, Test MSE: 0.003809
# Step: 900, Test MSE: 0.003667
# Step: 1000, Test MSE: 0.003730
# MSE (original scale): 277.84536453104084
# MSE (transformed scale): 0.003730235854163766
# Compression Ratio: 22.721758502896183
# Training time: 10.124837398529053
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009393
# Step: 200, Test MSE: 0.007591
# Step: 300, Test MSE: 0.007860
# Step: 400, Test MSE: 0.007446
# Step: 500, Test MSE: 0.006967
# Step: 600, Test MSE: 0.007529
# Step: 700, Test MSE: 0.006791
# Step: 800, Test MSE: 0.007273
# Step: 900, Test MSE: 0.007107
# Step: 1000, Test MSE: 0.006862
# MSE (original scale): 416.8152009077979
# MSE (transformed scale): 0.006862015929073095
# Compression Ratio: 22.721758502896183
# Training time: 10.126947164535522
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008641
# Step: 200, Test MSE: 0.006791
# Step: 300, Test MSE: 0.006400
# Step: 400, Test MSE: 0.006125
# Step: 500, Test MSE: 0.006005
# Step: 600, Test MSE: 0.006323
# Step: 700, Test MSE: 0.005786
# Step: 800, Test MSE: 0.005739
# Step: 900, Test MSE: 0.005670
# Step: 1000, Test MSE: 0.005624
# MSE (original scale): 350.92338363872153
# MSE (transformed scale): 0.00562354177236557
# Compression Ratio: 22.721758502896183
# Training time: 10.127428531646729
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009031
# Step: 200, Test MSE: 0.008142
# Step: 300, Test MSE: 0.007117
# Step: 400, Test MSE: 0.006913
# Step: 500, Test MSE: 0.006961
# Step: 600, Test MSE: 0.007326
# Step: 700, Test MSE: 0.007211
# Step: 800, Test MSE: 0.007353
# Step: 900, Test MSE: 0.007382
# Step: 1000, Test MSE: 0.006606
# MSE (original scale): 400.09326367971886
# MSE (transformed scale): 0.006606024224311113
# Compression Ratio: 22.721758502896183
# Training time: 10.126053810119629
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009455
# Step: 200, Test MSE: 0.008298
# Step: 300, Test MSE: 0.007831
# Step: 400, Test MSE: 0.007443
# Step: 500, Test MSE: 0.007425
# Step: 600, Test MSE: 0.007502
# Step: 700, Test MSE: 0.007444
# Step: 800, Test MSE: 0.007438
# Step: 900, Test MSE: 0.007134
# Step: 1000, Test MSE: 0.007239
# MSE (original scale): 429.4953564257028
# MSE (transformed scale): 0.007238601800054312
# Compression Ratio: 22.721758502896183
# Training time: 10.126487970352173
#
# Evaluating on data sample 1 jth time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009421
# Step: 200, Test MSE: 0.008331
# Step: 300, Test MSE: 0.007964
# Step: 400, Test MSE: 0.007717
# Step: 500, Test MSE: 0.007687
# Step: 600, Test MSE: 0.007147
# Step: 700, Test MSE: 0.007222
# Step: 800, Test MSE: 0.006878
# Step: 900, Test MSE: 0.007439
# Step: 1000, Test MSE: 0.006946
# MSE (original scale): 421.1774219272925
# MSE (transformed scale): 0.00694640027359128
# Compression Ratio: 22.721758502896183
# Training time: 10.124544858932495
#     model  data_sample                                          file_name  \
# 0   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 1   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 2   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 3   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 4   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 5   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 6   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 7   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 8   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 9   SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 10  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 11  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 12  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 13  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 14  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 15  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 16  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 17  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 18  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 19  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
#
#     original_mse  compression_ratio  transformed_mse  training_time     lr  \
# 0     323.289106          22.721759         0.005048      10.637411  0.001
# 1     262.326975          22.721759         0.003654      10.127505  0.001
# 2     259.920739          22.721759         0.004569      10.132578  0.001
# 3     409.538832          22.721759         0.006800      10.130965  0.001
# 4     275.403635          22.721759         0.003628      10.127035  0.001
# 5     248.159061          22.721759         0.004126      10.136204  0.001
# 6     332.136253          22.721759         0.005736      10.125061  0.001
# 7     274.943997          22.721759         0.003858      10.129194  0.001
# 8     344.324370          22.721759         0.005395      10.124467  0.001
# 9     332.126880          22.721759         0.005414      10.124295  0.001
# 10    356.632632          22.721759         0.005555      10.128140  0.001
# 11    480.218415          22.721759         0.007476      10.128517  0.001
# 12    270.734008          22.721759         0.003607      10.125757  0.001
# 13    440.303521          22.721759         0.007257      10.125564  0.001
# 14    277.845365          22.721759         0.003730      10.124837  0.001
# 15    416.815201          22.721759         0.006862      10.126947  0.001
# 16    350.923384          22.721759         0.005624      10.127429  0.001
# 17    400.093264          22.721759         0.006606      10.126054  0.001
# 18    429.495356          22.721759         0.007239      10.126488  0.001
# 19    421.177422          22.721759         0.006946      10.124545  0.001
#
#     in_features  hidden_features  hidden_layers  out_features device  \
# 0             3              128              3             1   cuda
# 1             3              128              3             1   cuda
# 2             3              128              3             1   cuda
# 3             3              128              3             1   cuda
# 4             3              128              3             1   cuda
# 5             3              128              3             1   cuda
# 6             3              128              3             1   cuda
# 7             3              128              3             1   cuda
# 8             3              128              3             1   cuda
# 9             3              128              3             1   cuda
# 10            3              128              3             1   cuda
# 11            3              128              3             1   cuda
# 12            3              128              3             1   cuda
# 13            3              128              3             1   cuda
# 14            3              128              3             1   cuda
# 15            3              128              3             1   cuda
# 16            3              128              3             1   cuda
# 17            3              128              3             1   cuda
# 18            3              128              3             1   cuda
# 19            3              128              3             1   cuda
#
#     max_iters  outermost_linear  first_omega_zero  hidden_omega_zero
# 0        1000              True               100                 45
# 1        1000              True               100                 45
# 2        1000              True               100                 45
# 3        1000              True               100                 45
# 4        1000              True               100                 45
# 5        1000              True               100                 45
# 6        1000              True               100                 45
# 7        1000              True               100                 45
# 8        1000              True               100                 45
# 9        1000              True               100                 45
# 10       1000              True               100                 45
# 11       1000              True               100                 45
# 12       1000              True               100                 45
# 13       1000              True               100                 45
# 14       1000              True               100                 45
# 15       1000              True               100                 45
# 16       1000              True               100                 45
# 17       1000              True               100                 45
# 18       1000              True               100                 45
# 19       1000              True               100                 45
