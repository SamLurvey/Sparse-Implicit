# %%
from importlib import reload
import torch

import testing_importance_sampling

from models.siren import SIREN
# Out:
# torch.Size([16, 128, 3])
# torch.Size([16, 128, 1])

# %%
reload(testing_importance_sampling)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [128],
    'hidden_layers': [3],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'sample_fraction':[.1,.2,.3,.4,.5,.6,.7,.8,.9,1],
    'max_iters':[1000]

}
#normal testing
#testing with only some nonzero values
#testing with nonzero values picked each number of steps

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True],"first_omega_zero":[100],"hidden_omega_zero":[45]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing_importance_sampling.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1 0th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011272
# Step: 200, Test MSE: 0.009417
# Step: 300, Test MSE: 0.008905
# Step: 400, Test MSE: 0.008714
# Step: 500, Test MSE: 0.008737
# Step: 600, Test MSE: 0.008636
# Step: 700, Test MSE: 0.008284
# Step: 800, Test MSE: 0.008185
# Step: 900, Test MSE: 0.008099
# Step: 1000, Test MSE: 0.008419
# MSE (original scale): 380.2032871067604
# MSE (transformed scale): 0.008418519049882889
# Compression Ratio: 22.721758502896183
# Training time: 2.267893075942993
#
# Evaluating on data sample 1 1th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011326
# Step: 200, Test MSE: 0.009925
# Step: 300, Test MSE: 0.009436
# Step: 400, Test MSE: 0.009319
# Step: 500, Test MSE: 0.008966
# Step: 600, Test MSE: 0.008968
# Step: 700, Test MSE: 0.008798
# Step: 800, Test MSE: 0.008760
# Step: 900, Test MSE: 0.008665
# Step: 1000, Test MSE: 0.008698
# MSE (original scale): 389.92593551288485
# MSE (transformed scale): 0.008698196150362492
# Compression Ratio: 22.721758502896183
# Training time: 1.8097124099731445
#
# Evaluating on data sample 1 2th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011405
# Step: 200, Test MSE: 0.010064
# Step: 300, Test MSE: 0.009422
# Step: 400, Test MSE: 0.008921
# Step: 500, Test MSE: 0.009146
# Step: 600, Test MSE: 0.008834
# Step: 700, Test MSE: 0.008481
# Step: 800, Test MSE: 0.008703
# Step: 900, Test MSE: 0.008423
# Step: 1000, Test MSE: 0.008334
# MSE (original scale): 371.42010882069945
# MSE (transformed scale): 0.008334163576364517
# Compression Ratio: 22.721758502896183
# Training time: 1.7942748069763184
#
# Evaluating on data sample 1 3th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011080
# Step: 200, Test MSE: 0.009726
# Step: 300, Test MSE: 0.009362
# Step: 400, Test MSE: 0.009180
# Step: 500, Test MSE: 0.008963
# Step: 600, Test MSE: 0.008834
# Step: 700, Test MSE: 0.008590
# Step: 800, Test MSE: 0.008596
# Step: 900, Test MSE: 0.008552
# Step: 1000, Test MSE: 0.008556
# MSE (original scale): 388.1940483287316
# MSE (transformed scale): 0.008555523119866848
# Compression Ratio: 22.721758502896183
# Training time: 1.8165347576141357
#
# Evaluating on data sample 1 4th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011307
# Step: 200, Test MSE: 0.009988
# Step: 300, Test MSE: 0.009072
# Step: 400, Test MSE: 0.009001
# Step: 500, Test MSE: 0.008606
# Step: 600, Test MSE: 0.008460
# Step: 700, Test MSE: 0.008503
# Step: 800, Test MSE: 0.008277
# Step: 900, Test MSE: 0.008344
# Step: 1000, Test MSE: 0.008046
# MSE (original scale): 370.0951893511546
# MSE (transformed scale): 0.008046471513807774
# Compression Ratio: 22.721758502896183
# Training time: 1.809291124343872
#
# Evaluating on data sample 1 5th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011348
# Step: 200, Test MSE: 0.009424
# Step: 300, Test MSE: 0.008957
# Step: 400, Test MSE: 0.008824
# Step: 500, Test MSE: 0.008617
# Step: 600, Test MSE: 0.008562
# Step: 700, Test MSE: 0.008514
# Step: 800, Test MSE: 0.008425
# Step: 900, Test MSE: 0.008547
# Step: 1000, Test MSE: 0.008507
# MSE (original scale): 386.32240027819614
# MSE (transformed scale): 0.00850696861743927
# Compression Ratio: 22.721758502896183
# Training time: 1.832204818725586
#
# Evaluating on data sample 1 6th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011162
# Step: 200, Test MSE: 0.009565
# Step: 300, Test MSE: 0.009094
# Step: 400, Test MSE: 0.008932
# Step: 500, Test MSE: 0.008952
# Step: 600, Test MSE: 0.008733
# Step: 700, Test MSE: 0.008644
# Step: 800, Test MSE: 0.008619
# Step: 900, Test MSE: 0.008459
# Step: 1000, Test MSE: 0.008542
# MSE (original scale): 386.35892528447124
# MSE (transformed scale): 0.008541690185666084
# Compression Ratio: 22.721758502896183
# Training time: 1.8253445625305176
#
# Evaluating on data sample 1 7th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011035
# Step: 200, Test MSE: 0.009526
# Step: 300, Test MSE: 0.009423
# Step: 400, Test MSE: 0.008949
# Step: 500, Test MSE: 0.008746
# Step: 600, Test MSE: 0.008904
# Step: 700, Test MSE: 0.008642
# Step: 800, Test MSE: 0.008473
# Step: 900, Test MSE: 0.008336
# Step: 1000, Test MSE: 0.008255
# MSE (original scale): 383.7427091177209
# MSE (transformed scale): 0.0082545792683959
# Compression Ratio: 22.721758502896183
# Training time: 1.8349695205688477
#
# Evaluating on data sample 1 8th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011249
# Step: 200, Test MSE: 0.009603
# Step: 300, Test MSE: 0.009209
# Step: 400, Test MSE: 0.008898
# Step: 500, Test MSE: 0.008729
# Step: 600, Test MSE: 0.008677
# Step: 700, Test MSE: 0.008785
# Step: 800, Test MSE: 0.008685
# Step: 900, Test MSE: 0.008532
# Step: 1000, Test MSE: 0.008549
# MSE (original scale): 384.0043794971553
# MSE (transformed scale): 0.008549193851649761
# Compression Ratio: 22.721758502896183
# Training time: 1.8492558002471924
#
# Evaluating on data sample 1 9th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011321
# Step: 200, Test MSE: 0.009697
# Step: 300, Test MSE: 0.009226
# Step: 400, Test MSE: 0.008982
# Step: 500, Test MSE: 0.008961
# Step: 600, Test MSE: 0.008737
# Step: 700, Test MSE: 0.008638
# Step: 800, Test MSE: 0.008724
# Step: 900, Test MSE: 0.008538
# Step: 1000, Test MSE: 0.008617
# MSE (original scale): 380.4215873912316
# MSE (transformed scale): 0.00861694011837244
# Compression Ratio: 22.721758502896183
# Training time: 1.8388614654541016
#
# Evaluating on data sample 1 10th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011466
# Step: 200, Test MSE: 0.009793
# Step: 300, Test MSE: 0.009580
# Step: 400, Test MSE: 0.008866
# Step: 500, Test MSE: 0.008776
# Step: 600, Test MSE: 0.008628
# Step: 700, Test MSE: 0.008787
# Step: 800, Test MSE: 0.008500
# Step: 900, Test MSE: 0.008406
# Step: 1000, Test MSE: 0.008787
# MSE (original scale): 441.92099256400604
# MSE (transformed scale): 0.008787242695689201
# Compression Ratio: 22.721758502896183
# Training time: 1.8889186382293701
#
# Evaluating on data sample 1 11th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011173
# Step: 200, Test MSE: 0.009688
# Step: 300, Test MSE: 0.009307
# Step: 400, Test MSE: 0.009028
# Step: 500, Test MSE: 0.008985
# Step: 600, Test MSE: 0.008825
# Step: 700, Test MSE: 0.008770
# Step: 800, Test MSE: 0.008574
# Step: 900, Test MSE: 0.008729
# Step: 1000, Test MSE: 0.008853
# MSE (original scale): 398.7094393197791
# MSE (transformed scale): 0.008852790109813213
# Compression Ratio: 22.721758502896183
# Training time: 1.8200535774230957
#
# Evaluating on data sample 1 12th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010958
# Step: 200, Test MSE: 0.009793
# Step: 300, Test MSE: 0.009134
# Step: 400, Test MSE: 0.008961
# Step: 500, Test MSE: 0.008952
# Step: 600, Test MSE: 0.008901
# Step: 700, Test MSE: 0.008458
# Step: 800, Test MSE: 0.008662
# Step: 900, Test MSE: 0.008207
# Step: 1000, Test MSE: 0.008539
# MSE (original scale): 389.22793387090024
# MSE (transformed scale): 0.008538519032299519
# Compression Ratio: 22.721758502896183
# Training time: 1.8291029930114746
#
# Evaluating on data sample 1 13th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011526
# Step: 200, Test MSE: 0.009521
# Step: 300, Test MSE: 0.009132
# Step: 400, Test MSE: 0.009010
# Step: 500, Test MSE: 0.008711
# Step: 600, Test MSE: 0.008485
# Step: 700, Test MSE: 0.008564
# Step: 800, Test MSE: 0.008472
# Step: 900, Test MSE: 0.008457
# Step: 1000, Test MSE: 0.008305
# MSE (original scale): 374.33100500962183
# MSE (transformed scale): 0.008304520510137081
# Compression Ratio: 22.721758502896183
# Training time: 1.8533599376678467
#
# Evaluating on data sample 1 14th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011036
# Step: 200, Test MSE: 0.009726
# Step: 300, Test MSE: 0.009183
# Step: 400, Test MSE: 0.008989
# Step: 500, Test MSE: 0.009108
# Step: 600, Test MSE: 0.008976
# Step: 700, Test MSE: 0.008849
# Step: 800, Test MSE: 0.008972
# Step: 900, Test MSE: 0.008777
# Step: 1000, Test MSE: 0.008692
# MSE (original scale): 389.54540035140565
# MSE (transformed scale): 0.008692135103046894
# Compression Ratio: 22.721758502896183
# Training time: 1.8317351341247559
#
# Evaluating on data sample 1 15th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011147
# Step: 200, Test MSE: 0.009559
# Step: 300, Test MSE: 0.008968
# Step: 400, Test MSE: 0.008569
# Step: 500, Test MSE: 0.008373
# Step: 600, Test MSE: 0.008415
# Step: 700, Test MSE: 0.008140
# Step: 800, Test MSE: 0.008150
# Step: 900, Test MSE: 0.007960
# Step: 1000, Test MSE: 0.007805
# MSE (original scale): 356.53697864374163
# MSE (transformed scale): 0.007804804015904665
# Compression Ratio: 22.721758502896183
# Training time: 1.8156964778900146
#
# Evaluating on data sample 1 16th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011169
# Step: 200, Test MSE: 0.009386
# Step: 300, Test MSE: 0.008952
# Step: 400, Test MSE: 0.008594
# Step: 500, Test MSE: 0.008570
# Step: 600, Test MSE: 0.008449
# Step: 700, Test MSE: 0.008302
# Step: 800, Test MSE: 0.008387
# Step: 900, Test MSE: 0.008280
# Step: 1000, Test MSE: 0.008358
# MSE (original scale): 379.00337286646584
# MSE (transformed scale): 0.008357630111277103
# Compression Ratio: 22.721758502896183
# Training time: 1.8508632183074951
#
# Evaluating on data sample 1 17th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011617
# Step: 200, Test MSE: 0.009897
# Step: 300, Test MSE: 0.009273
# Step: 400, Test MSE: 0.009238
# Step: 500, Test MSE: 0.009220
# Step: 600, Test MSE: 0.009109
# Step: 700, Test MSE: 0.009025
# Step: 800, Test MSE: 0.009039
# Step: 900, Test MSE: 0.008922
# Step: 1000, Test MSE: 0.008785
# MSE (original scale): 390.7572647360274
# MSE (transformed scale): 0.008785496465861797
# Compression Ratio: 22.721758502896183
# Training time: 1.854062795639038
#
# Evaluating on data sample 1 18th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011402
# Step: 200, Test MSE: 0.009723
# Step: 300, Test MSE: 0.008928
# Step: 400, Test MSE: 0.008690
# Step: 500, Test MSE: 0.008555
# Step: 600, Test MSE: 0.008524
# Step: 700, Test MSE: 0.008259
# Step: 800, Test MSE: 0.008247
# Step: 900, Test MSE: 0.008467
# Step: 1000, Test MSE: 0.008211
# MSE (original scale): 375.72377269494643
# MSE (transformed scale): 0.008211420848965645
# Compression Ratio: 22.721758502896183
# Training time: 1.8581809997558594
#
# Evaluating on data sample 1 19th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.011584
# Step: 200, Test MSE: 0.009747
# Step: 300, Test MSE: 0.009223
# Step: 400, Test MSE: 0.009287
# Step: 500, Test MSE: 0.009130
# Step: 600, Test MSE: 0.008920
# Step: 700, Test MSE: 0.008792
# Step: 800, Test MSE: 0.008851
# Step: 900, Test MSE: 0.008607
# Step: 1000, Test MSE: 0.008650
# MSE (original scale): 376.7907593917336
# MSE (transformed scale): 0.00864956434816122
# Compression Ratio: 22.721758502896183
# Training time: 1.8807542324066162
#
# Evaluating on data sample 1 0th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009904
# Step: 200, Test MSE: 0.008743
# Step: 300, Test MSE: 0.008015
# Step: 400, Test MSE: 0.007744
# Step: 500, Test MSE: 0.008155
# Step: 600, Test MSE: 0.007789
# Step: 700, Test MSE: 0.007829
# Step: 800, Test MSE: 0.008043
# Step: 900, Test MSE: 0.007772
# Step: 1000, Test MSE: 0.007755
# MSE (original scale): 347.12015509956495
# MSE (transformed scale): 0.007754927035421133
# Compression Ratio: 22.721758502896183
# Training time: 2.9897403717041016
#
# Evaluating on data sample 1 1th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009994
# Step: 200, Test MSE: 0.008618
# Step: 300, Test MSE: 0.008394
# Step: 400, Test MSE: 0.008146
# Step: 500, Test MSE: 0.008008
# Step: 600, Test MSE: 0.007923
# Step: 700, Test MSE: 0.008125
# Step: 800, Test MSE: 0.007778
# Step: 900, Test MSE: 0.007905
# Step: 1000, Test MSE: 0.007902
# MSE (original scale): 355.47906208165995
# MSE (transformed scale): 0.007901515811681747
# Compression Ratio: 22.721758502896183
# Training time: 2.9907710552215576
#
# Evaluating on data sample 1 2th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009877
# Step: 200, Test MSE: 0.008530
# Step: 300, Test MSE: 0.008146
# Step: 400, Test MSE: 0.007866
# Step: 500, Test MSE: 0.007765
# Step: 600, Test MSE: 0.007523
# Step: 700, Test MSE: 0.007531
# Step: 800, Test MSE: 0.007774
# Step: 900, Test MSE: 0.007625
# Step: 1000, Test MSE: 0.007617
# MSE (original scale): 334.46471171142906
# MSE (transformed scale): 0.0076167890802025795
# Compression Ratio: 22.721758502896183
# Training time: 3.019174337387085
#
# Evaluating on data sample 1 3th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009829
# Step: 200, Test MSE: 0.008433
# Step: 300, Test MSE: 0.008075
# Step: 400, Test MSE: 0.007852
# Step: 500, Test MSE: 0.007913
# Step: 600, Test MSE: 0.007689
# Step: 700, Test MSE: 0.007769
# Step: 800, Test MSE: 0.007717
# Step: 900, Test MSE: 0.007713
# Step: 1000, Test MSE: 0.007680
# MSE (original scale): 337.30964613662985
# MSE (transformed scale): 0.007679836358875036
# Compression Ratio: 22.721758502896183
# Training time: 2.986135244369507
#
# Evaluating on data sample 1 4th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009757
# Step: 200, Test MSE: 0.008127
# Step: 300, Test MSE: 0.007967
# Step: 400, Test MSE: 0.007713
# Step: 500, Test MSE: 0.007489
# Step: 600, Test MSE: 0.007591
# Step: 700, Test MSE: 0.007294
# Step: 800, Test MSE: 0.007288
# Step: 900, Test MSE: 0.007113
# Step: 1000, Test MSE: 0.007349
# MSE (original scale): 324.7401154095549
# MSE (transformed scale): 0.007349194027483463
# Compression Ratio: 22.721758502896183
# Training time: 2.9954047203063965
#
# Evaluating on data sample 1 5th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009869
# Step: 200, Test MSE: 0.008550
# Step: 300, Test MSE: 0.008098
# Step: 400, Test MSE: 0.007875
# Step: 500, Test MSE: 0.007751
# Step: 600, Test MSE: 0.007637
# Step: 700, Test MSE: 0.007677
# Step: 800, Test MSE: 0.007442
# Step: 900, Test MSE: 0.007279
# Step: 1000, Test MSE: 0.007365
# MSE (original scale): 320.16639736027446
# MSE (transformed scale): 0.0073653520084917545
# Compression Ratio: 22.721758502896183
# Training time: 2.9877498149871826
#
# Evaluating on data sample 1 6th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010245
# Step: 200, Test MSE: 0.008597
# Step: 300, Test MSE: 0.008120
# Step: 400, Test MSE: 0.008013
# Step: 500, Test MSE: 0.007832
# Step: 600, Test MSE: 0.007903
# Step: 700, Test MSE: 0.007752
# Step: 800, Test MSE: 0.007741
# Step: 900, Test MSE: 0.007633
# Step: 1000, Test MSE: 0.007712
# MSE (original scale): 343.1677033655455
# MSE (transformed scale): 0.007711953017860651
# Compression Ratio: 22.721758502896183
# Training time: 3.0128064155578613
#
# Evaluating on data sample 1 7th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010075
# Step: 200, Test MSE: 0.008733
# Step: 300, Test MSE: 0.008368
# Step: 400, Test MSE: 0.008121
# Step: 500, Test MSE: 0.008051
# Step: 600, Test MSE: 0.007907
# Step: 700, Test MSE: 0.008029
# Step: 800, Test MSE: 0.007751
# Step: 900, Test MSE: 0.007799
# Step: 1000, Test MSE: 0.007748
# MSE (original scale): 340.87020869938084
# MSE (transformed scale): 0.007748463191092014
# Compression Ratio: 22.721758502896183
# Training time: 2.9898085594177246
#
# Evaluating on data sample 1 8th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009815
# Step: 200, Test MSE: 0.008338
# Step: 300, Test MSE: 0.007840
# Step: 400, Test MSE: 0.007567
# Step: 500, Test MSE: 0.007580
# Step: 600, Test MSE: 0.007385
# Step: 700, Test MSE: 0.007375
# Step: 800, Test MSE: 0.007099
# Step: 900, Test MSE: 0.007247
# Step: 1000, Test MSE: 0.007114
# MSE (original scale): 313.8276125334672
# MSE (transformed scale): 0.0071142143569886684
# Compression Ratio: 22.721758502896183
# Training time: 3.0017106533050537
#
# Evaluating on data sample 1 9th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009450
# Step: 200, Test MSE: 0.008054
# Step: 300, Test MSE: 0.007746
# Step: 400, Test MSE: 0.007610
# Step: 500, Test MSE: 0.007335
# Step: 600, Test MSE: 0.007160
# Step: 700, Test MSE: 0.007403
# Step: 800, Test MSE: 0.007254
# Step: 900, Test MSE: 0.007235
# Step: 1000, Test MSE: 0.007160
# MSE (original scale): 317.6974499560743
# MSE (transformed scale): 0.007159608881920576
# Compression Ratio: 22.721758502896183
# Training time: 2.9905571937561035
#
# Evaluating on data sample 1 10th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009884
# Step: 200, Test MSE: 0.008249
# Step: 300, Test MSE: 0.007623
# Step: 400, Test MSE: 0.007482
# Step: 500, Test MSE: 0.007705
# Step: 600, Test MSE: 0.007259
# Step: 700, Test MSE: 0.007068
# Step: 800, Test MSE: 0.007297
# Step: 900, Test MSE: 0.007241
# Step: 1000, Test MSE: 0.006944
# MSE (original scale): 308.6332439131526
# MSE (transformed scale): 0.006944349966943264
# Compression Ratio: 22.721758502896183
# Training time: 3.055154323577881
#
# Evaluating on data sample 1 11th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009910
# Step: 200, Test MSE: 0.008310
# Step: 300, Test MSE: 0.007748
# Step: 400, Test MSE: 0.007564
# Step: 500, Test MSE: 0.007608
# Step: 600, Test MSE: 0.007417
# Step: 700, Test MSE: 0.007314
# Step: 800, Test MSE: 0.007324
# Step: 900, Test MSE: 0.007220
# Step: 1000, Test MSE: 0.007082
# MSE (original scale): 316.1488140060241
# MSE (transformed scale): 0.007082145195454359
# Compression Ratio: 22.721758502896183
# Training time: 2.993285894393921
#
# Evaluating on data sample 1 12th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009868
# Step: 200, Test MSE: 0.009016
# Step: 300, Test MSE: 0.008153
# Step: 400, Test MSE: 0.008098
# Step: 500, Test MSE: 0.007821
# Step: 600, Test MSE: 0.007713
# Step: 700, Test MSE: 0.007674
# Step: 800, Test MSE: 0.007646
# Step: 900, Test MSE: 0.007654
# Step: 1000, Test MSE: 0.007490
# MSE (original scale): 320.1146905329652
# MSE (transformed scale): 0.007490033749490976
# Compression Ratio: 22.721758502896183
# Training time: 3.0086374282836914
#
# Evaluating on data sample 1 13th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010060
# Step: 200, Test MSE: 0.008977
# Step: 300, Test MSE: 0.008408
# Step: 400, Test MSE: 0.008198
# Step: 500, Test MSE: 0.008151
# Step: 600, Test MSE: 0.007733
# Step: 700, Test MSE: 0.007900
# Step: 800, Test MSE: 0.008002
# Step: 900, Test MSE: 0.007746
# Step: 1000, Test MSE: 0.007968
# MSE (original scale): 340.91884595674367
# MSE (transformed scale): 0.007967712357640266
# Compression Ratio: 22.721758502896183
# Training time: 3.025120735168457
#
# Evaluating on data sample 1 14th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009825
# Step: 200, Test MSE: 0.008571
# Step: 300, Test MSE: 0.008356
# Step: 400, Test MSE: 0.008047
# Step: 500, Test MSE: 0.007972
# Step: 600, Test MSE: 0.008119
# Step: 700, Test MSE: 0.007948
# Step: 800, Test MSE: 0.007692
# Step: 900, Test MSE: 0.007755
# Step: 1000, Test MSE: 0.007616
# MSE (original scale): 327.45233146126174
# MSE (transformed scale): 0.0076162805780768394
# Compression Ratio: 22.721758502896183
# Training time: 3.023728132247925
#
# Evaluating on data sample 1 15th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010118
# Step: 200, Test MSE: 0.008510
# Step: 300, Test MSE: 0.008177
# Step: 400, Test MSE: 0.008358
# Step: 500, Test MSE: 0.007627
# Step: 600, Test MSE: 0.007493
# Step: 700, Test MSE: 0.007596
# Step: 800, Test MSE: 0.007441
# Step: 900, Test MSE: 0.007512
# Step: 1000, Test MSE: 0.007394
# MSE (original scale): 330.1896701388889
# MSE (transformed scale): 0.007393790874630213
# Compression Ratio: 22.721758502896183
# Training time: 2.998992443084717
#
# Evaluating on data sample 1 16th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010541
# Step: 200, Test MSE: 0.008696
# Step: 300, Test MSE: 0.008225
# Step: 400, Test MSE: 0.008111
# Step: 500, Test MSE: 0.007813
# Step: 600, Test MSE: 0.007864
# Step: 700, Test MSE: 0.007888
# Step: 800, Test MSE: 0.007823
# Step: 900, Test MSE: 0.007867
# Step: 1000, Test MSE: 0.007749
# MSE (original scale): 332.25259109354084
# MSE (transformed scale): 0.0077485679648816586
# Compression Ratio: 22.721758502896183
# Training time: 3.0082991123199463
#
# Evaluating on data sample 1 17th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010072
# Step: 200, Test MSE: 0.008638
# Step: 300, Test MSE: 0.008090
# Step: 400, Test MSE: 0.007902
# Step: 500, Test MSE: 0.008025
# Step: 600, Test MSE: 0.007685
# Step: 700, Test MSE: 0.007650
# Step: 800, Test MSE: 0.007604
# Step: 900, Test MSE: 0.007621
# Step: 1000, Test MSE: 0.007590
# MSE (original scale): 334.63240331116134
# MSE (transformed scale): 0.007589700166136026
# Compression Ratio: 22.721758502896183
# Training time: 2.9974710941314697
#
# Evaluating on data sample 1 18th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010268
# Step: 200, Test MSE: 0.008928
# Step: 300, Test MSE: 0.008582
# Step: 400, Test MSE: 0.008386
# Step: 500, Test MSE: 0.008204
# Step: 600, Test MSE: 0.007851
# Step: 700, Test MSE: 0.007814
# Step: 800, Test MSE: 0.008209
# Step: 900, Test MSE: 0.008189
# Step: 1000, Test MSE: 0.007780
# MSE (original scale): 340.18391796352074
# MSE (transformed scale): 0.0077798860147595406
# Compression Ratio: 22.721758502896183
# Training time: 2.9957807064056396
#
# Evaluating on data sample 1 19th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.2
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009944
# Step: 200, Test MSE: 0.008608
# Step: 300, Test MSE: 0.008308
# Step: 400, Test MSE: 0.008140
# Step: 500, Test MSE: 0.008056
# Step: 600, Test MSE: 0.008054
# Step: 700, Test MSE: 0.008051
# Step: 800, Test MSE: 0.007987
# Step: 900, Test MSE: 0.008059
# Step: 1000, Test MSE: 0.007718
# MSE (original scale): 335.11005088060574
# MSE (transformed scale): 0.007717994973063469
# Compression Ratio: 22.721758502896183
# Training time: 3.0074586868286133
#
# Evaluating on data sample 1 0th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009589
# Step: 200, Test MSE: 0.008438
# Step: 300, Test MSE: 0.007868
# Step: 400, Test MSE: 0.007600
# Step: 500, Test MSE: 0.007576
# Step: 600, Test MSE: 0.007476
# Step: 700, Test MSE: 0.007880
# Step: 800, Test MSE: 0.007458
# Step: 900, Test MSE: 0.007477
# Step: 1000, Test MSE: 0.007418
# MSE (original scale): 331.1124641796352
# MSE (transformed scale): 0.007418354041874409
# Compression Ratio: 22.721758502896183
# Training time: 4.048665761947632
#
# Evaluating on data sample 1 1th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009382
# Step: 200, Test MSE: 0.008075
# Step: 300, Test MSE: 0.007722
# Step: 400, Test MSE: 0.007541
# Step: 500, Test MSE: 0.007393
# Step: 600, Test MSE: 0.007262
# Step: 700, Test MSE: 0.007254
# Step: 800, Test MSE: 0.007310
# Step: 900, Test MSE: 0.007535
# Step: 1000, Test MSE: 0.007137
# MSE (original scale): 317.32167602702475
# MSE (transformed scale): 0.0071373675018548965
# Compression Ratio: 22.721758502896183
# Training time: 4.009231805801392
#
# Evaluating on data sample 1 2th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009288
# Step: 200, Test MSE: 0.007982
# Step: 300, Test MSE: 0.007688
# Step: 400, Test MSE: 0.007467
# Step: 500, Test MSE: 0.007265
# Step: 600, Test MSE: 0.007216
# Step: 700, Test MSE: 0.007413
# Step: 800, Test MSE: 0.007039
# Step: 900, Test MSE: 0.006882
# Step: 1000, Test MSE: 0.007301
# MSE (original scale): 323.3985852263219
# MSE (transformed scale): 0.0073009394109249115
# Compression Ratio: 22.721758502896183
# Training time: 4.010747671127319
#
# Evaluating on data sample 1 3th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009487
# Step: 200, Test MSE: 0.008499
# Step: 300, Test MSE: 0.007739
# Step: 400, Test MSE: 0.007441
# Step: 500, Test MSE: 0.007438
# Step: 600, Test MSE: 0.007240
# Step: 700, Test MSE: 0.007342
# Step: 800, Test MSE: 0.007263
# Step: 900, Test MSE: 0.007368
# Step: 1000, Test MSE: 0.007439
# MSE (original scale): 321.6063603371821
# MSE (transformed scale): 0.007439353968948126
# Compression Ratio: 22.721758502896183
# Training time: 4.007645845413208
#
# Evaluating on data sample 1 4th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009419
# Step: 200, Test MSE: 0.008495
# Step: 300, Test MSE: 0.008011
# Step: 400, Test MSE: 0.007864
# Step: 500, Test MSE: 0.007692
# Step: 600, Test MSE: 0.007792
# Step: 700, Test MSE: 0.007662
# Step: 800, Test MSE: 0.007704
# Step: 900, Test MSE: 0.007675
# Step: 1000, Test MSE: 0.007474
# MSE (original scale): 320.91896230756356
# MSE (transformed scale): 0.0074742198921740055
# Compression Ratio: 22.721758502896183
# Training time: 4.006655693054199
#
# Evaluating on data sample 1 5th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008784
# Step: 200, Test MSE: 0.007865
# Step: 300, Test MSE: 0.007183
# Step: 400, Test MSE: 0.007314
# Step: 500, Test MSE: 0.006778
# Step: 600, Test MSE: 0.006935
# Step: 700, Test MSE: 0.006936
# Step: 800, Test MSE: 0.006633
# Step: 900, Test MSE: 0.006951
# Step: 1000, Test MSE: 0.006666
# MSE (original scale): 293.1604373222055
# MSE (transformed scale): 0.006665993016213179
# Compression Ratio: 22.721758502896183
# Training time: 4.0055224895477295
#
# Evaluating on data sample 1 6th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009548
# Step: 200, Test MSE: 0.008098
# Step: 300, Test MSE: 0.007661
# Step: 400, Test MSE: 0.007524
# Step: 500, Test MSE: 0.007504
# Step: 600, Test MSE: 0.007279
# Step: 700, Test MSE: 0.007354
# Step: 800, Test MSE: 0.007445
# Step: 900, Test MSE: 0.007178
# Step: 1000, Test MSE: 0.007089
# MSE (original scale): 307.8459436705154
# MSE (transformed scale): 0.007089301943778992
# Compression Ratio: 22.721758502896183
# Training time: 4.055459976196289
#
# Evaluating on data sample 1 7th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008963
# Step: 200, Test MSE: 0.007657
# Step: 300, Test MSE: 0.007445
# Step: 400, Test MSE: 0.007006
# Step: 500, Test MSE: 0.007101
# Step: 600, Test MSE: 0.007004
# Step: 700, Test MSE: 0.006926
# Step: 800, Test MSE: 0.006825
# Step: 900, Test MSE: 0.006853
# Step: 1000, Test MSE: 0.006864
# MSE (original scale): 296.84590575845044
# MSE (transformed scale): 0.0068635595962405205
# Compression Ratio: 22.721758502896183
# Training time: 4.0310680866241455
#
# Evaluating on data sample 1 8th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009462
# Step: 200, Test MSE: 0.007829
# Step: 300, Test MSE: 0.007613
# Step: 400, Test MSE: 0.007311
# Step: 500, Test MSE: 0.007164
# Step: 600, Test MSE: 0.007274
# Step: 700, Test MSE: 0.007247
# Step: 800, Test MSE: 0.006996
# Step: 900, Test MSE: 0.006867
# Step: 1000, Test MSE: 0.006964
# MSE (original scale): 304.255695960927
# MSE (transformed scale): 0.00696393521502614
# Compression Ratio: 22.721758502896183
# Training time: 4.009058952331543
#
# Evaluating on data sample 1 9th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009615
# Step: 200, Test MSE: 0.008314
# Step: 300, Test MSE: 0.008043
# Step: 400, Test MSE: 0.007956
# Step: 500, Test MSE: 0.007660
# Step: 600, Test MSE: 0.008104
# Step: 700, Test MSE: 0.007615
# Step: 800, Test MSE: 0.008193
# Step: 900, Test MSE: 0.007570
# Step: 1000, Test MSE: 0.008246
# MSE (original scale): 343.67833181685074
# MSE (transformed scale): 0.008246364071965218
# Compression Ratio: 22.721758502896183
# Training time: 4.117252349853516
#
# Evaluating on data sample 1 10th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009174
# Step: 200, Test MSE: 0.007746
# Step: 300, Test MSE: 0.007473
# Step: 400, Test MSE: 0.007363
# Step: 500, Test MSE: 0.007346
# Step: 600, Test MSE: 0.007197
# Step: 700, Test MSE: 0.007104
# Step: 800, Test MSE: 0.007009
# Step: 900, Test MSE: 0.007033
# Step: 1000, Test MSE: 0.007133
# MSE (original scale): 314.4472904639391
# MSE (transformed scale): 0.007133265491575003
# Compression Ratio: 22.721758502896183
# Training time: 4.009353399276733
#
# Evaluating on data sample 1 11th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009989
# Step: 200, Test MSE: 0.008661
# Step: 300, Test MSE: 0.008110
# Step: 400, Test MSE: 0.007802
# Step: 500, Test MSE: 0.007830
# Step: 600, Test MSE: 0.007482
# Step: 700, Test MSE: 0.007779
# Step: 800, Test MSE: 0.007694
# Step: 900, Test MSE: 0.007488
# Step: 1000, Test MSE: 0.007248
# MSE (original scale): 300.64380830614124
# MSE (transformed scale): 0.007248336914926767
# Compression Ratio: 22.721758502896183
# Training time: 4.004090785980225
#
# Evaluating on data sample 1 12th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009219
# Step: 200, Test MSE: 0.008295
# Step: 300, Test MSE: 0.007278
# Step: 400, Test MSE: 0.007352
# Step: 500, Test MSE: 0.007101
# Step: 600, Test MSE: 0.007161
# Step: 700, Test MSE: 0.006764
# Step: 800, Test MSE: 0.006797
# Step: 900, Test MSE: 0.006813
# Step: 1000, Test MSE: 0.006699
# MSE (original scale): 294.5781289219378
# MSE (transformed scale): 0.006699298974126577
# Compression Ratio: 22.721758502896183
# Training time: 4.004623174667358
#
# Evaluating on data sample 1 13th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009640
# Step: 200, Test MSE: 0.008191
# Step: 300, Test MSE: 0.007852
# Step: 400, Test MSE: 0.007447
# Step: 500, Test MSE: 0.007336
# Step: 600, Test MSE: 0.007385
# Step: 700, Test MSE: 0.007458
# Step: 800, Test MSE: 0.007402
# Step: 900, Test MSE: 0.007259
# Step: 1000, Test MSE: 0.007497
# MSE (original scale): 328.40601860567267
# MSE (transformed scale): 0.007496642880141735
# Compression Ratio: 22.721758502896183
# Training time: 4.004141569137573
#
# Evaluating on data sample 1 14th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009512
# Step: 200, Test MSE: 0.008100
# Step: 300, Test MSE: 0.007796
# Step: 400, Test MSE: 0.007397
# Step: 500, Test MSE: 0.007400
# Step: 600, Test MSE: 0.007433
# Step: 700, Test MSE: 0.007181
# Step: 800, Test MSE: 0.007116
# Step: 900, Test MSE: 0.007014
# Step: 1000, Test MSE: 0.007070
# MSE (original scale): 303.6375920348059
# MSE (transformed scale): 0.007070336956530809
# Compression Ratio: 22.721758502896183
# Training time: 4.030315399169922
#
# Evaluating on data sample 1 15th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009919
# Step: 200, Test MSE: 0.008591
# Step: 300, Test MSE: 0.007934
# Step: 400, Test MSE: 0.007878
# Step: 500, Test MSE: 0.007384
# Step: 600, Test MSE: 0.007478
# Step: 700, Test MSE: 0.007651
# Step: 800, Test MSE: 0.007303
# Step: 900, Test MSE: 0.007353
# Step: 1000, Test MSE: 0.007667
# MSE (original scale): 323.0866146879183
# MSE (transformed scale): 0.007667286321520805
# Compression Ratio: 22.721758502896183
# Training time: 4.003028869628906
#
# Evaluating on data sample 1 16th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009471
# Step: 200, Test MSE: 0.007997
# Step: 300, Test MSE: 0.007533
# Step: 400, Test MSE: 0.007407
# Step: 500, Test MSE: 0.007236
# Step: 600, Test MSE: 0.007072
# Step: 700, Test MSE: 0.007168
# Step: 800, Test MSE: 0.007395
# Step: 900, Test MSE: 0.007019
# Step: 1000, Test MSE: 0.007042
# MSE (original scale): 316.0490987387048
# MSE (transformed scale): 0.007042132318019867
# Compression Ratio: 22.721758502896183
# Training time: 4.005818128585815
#
# Evaluating on data sample 1 17th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 0.3
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008898
# Step: 200, Test MSE: 0.007523
# Step: 300, Test MSE: 0.007342
# Step: 400, Test MSE: 0.007778
# Step: 500, Test MSE: 0.007233
# Step: 600, Test MSE: 0.007674
# Step: 700, Test MSE: 0.007287
# Step: 800, Test MSE: 0.006936
# Step: 900, Test MSE: 0.007527
# Step: 1000, Test MSE: 0.006819
# MSE (original scale): 295.61283545640896
# MSE (transformed scale): 0.006819265894591808
# Compression Ratio: 22.721758502896183
# Training time: 4.006404638290405
#
# Evaluating on data sample 1 18th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# ...
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008925
# Step: 200, Test MSE: 0.007661
# Step: 300, Test MSE: 0.007416
# Step: 400, Test MSE: 0.006960
# Step: 500, Test MSE: 0.006730
# Step: 600, Test MSE: 0.006881
# Step: 700, Test MSE: 0.007082
# Step: 800, Test MSE: 0.006952
# Step: 900, Test MSE: 0.006943
# Step: 1000, Test MSE: 0.006786
# MSE (original scale): 291.90331116131193
# MSE (transformed scale): 0.006786022335290909
# Compression Ratio: 22.721758502896183
# Training time: 10.57802700996399
#
# Evaluating on data sample 1 6th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.010281
# Step: 200, Test MSE: 0.008180
# Step: 300, Test MSE: 0.007200
# Step: 400, Test MSE: 0.007456
# Step: 500, Test MSE: 0.007105
# Step: 600, Test MSE: 0.007974
# Step: 700, Test MSE: 0.007323
# Step: 800, Test MSE: 0.007158
# Step: 900, Test MSE: 0.006869
# Step: 1000, Test MSE: 0.006823
# MSE (original scale): 299.78711460425035
# MSE (transformed scale): 0.0068225073628127575
# Compression Ratio: 22.721758502896183
# Training time: 10.575789213180542
#
# Evaluating on data sample 1 7th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008870
# Step: 200, Test MSE: 0.007613
# Step: 300, Test MSE: 0.007279
# Step: 400, Test MSE: 0.006952
# Step: 500, Test MSE: 0.006997
# Step: 600, Test MSE: 0.007291
# Step: 700, Test MSE: 0.007037
# Step: 800, Test MSE: 0.006868
# Step: 900, Test MSE: 0.006915
# Step: 1000, Test MSE: 0.006888
# MSE (original scale): 299.941390562249
# MSE (transformed scale): 0.006887769792228937
# Compression Ratio: 22.721758502896183
# Training time: 10.583137512207031
#
# Evaluating on data sample 1 8th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009286
# Step: 200, Test MSE: 0.007767
# Step: 300, Test MSE: 0.007163
# Step: 400, Test MSE: 0.007713
# Step: 500, Test MSE: 0.007043
# Step: 600, Test MSE: 0.007392
# Step: 700, Test MSE: 0.007205
# Step: 800, Test MSE: 0.006850
# Step: 900, Test MSE: 0.006924
# Step: 1000, Test MSE: 0.006886
# MSE (original scale): 295.07631437207164
# MSE (transformed scale): 0.006885666400194168
# Compression Ratio: 22.721758502896183
# Training time: 10.578010320663452
#
# Evaluating on data sample 1 9th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008976
# Step: 200, Test MSE: 0.007651
# Step: 300, Test MSE: 0.007345
# Step: 400, Test MSE: 0.006858
# Step: 500, Test MSE: 0.008320
# Step: 600, Test MSE: 0.007459
# Step: 700, Test MSE: 0.006662
# Step: 800, Test MSE: 0.006658
# Step: 900, Test MSE: 0.006698
# Step: 1000, Test MSE: 0.006723
# MSE (original scale): 285.99695396168005
# MSE (transformed scale): 0.006722813937813044
# Compression Ratio: 22.721758502896183
# Training time: 10.57300066947937
#
# Evaluating on data sample 1 10th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009118
# Step: 200, Test MSE: 0.007911
# Step: 300, Test MSE: 0.007415
# Step: 400, Test MSE: 0.007393
# Step: 500, Test MSE: 0.006860
# Step: 600, Test MSE: 0.007097
# Step: 700, Test MSE: 0.007220
# Step: 800, Test MSE: 0.006672
# Step: 900, Test MSE: 0.006739
# Step: 1000, Test MSE: 0.007303
# MSE (original scale): 303.00468017904956
# MSE (transformed scale): 0.007303055841475725
# Compression Ratio: 22.721758502896183
# Training time: 10.580044746398926
#
# Evaluating on data sample 1 11th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009105
# Step: 200, Test MSE: 0.007477
# Step: 300, Test MSE: 0.007610
# Step: 400, Test MSE: 0.007106
# Step: 500, Test MSE: 0.006493
# Step: 600, Test MSE: 0.006617
# Step: 700, Test MSE: 0.006725
# Step: 800, Test MSE: 0.006558
# Step: 900, Test MSE: 0.006525
# Step: 1000, Test MSE: 0.007497
# MSE (original scale): 338.3351047418842
# MSE (transformed scale): 0.00749719375744462
# Compression Ratio: 22.721758502896183
# Training time: 10.626369714736938
#
# Evaluating on data sample 1 12th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008965
# Step: 200, Test MSE: 0.007339
# Step: 300, Test MSE: 0.006990
# Step: 400, Test MSE: 0.006735
# Step: 500, Test MSE: 0.006603
# Step: 600, Test MSE: 0.006592
# Step: 700, Test MSE: 0.006506
# Step: 800, Test MSE: 0.006641
# Step: 900, Test MSE: 0.006655
# Step: 1000, Test MSE: 0.006414
# MSE (original scale): 276.60394573084005
# MSE (transformed scale): 0.006413969211280346
# Compression Ratio: 22.721758502896183
# Training time: 10.610028982162476
#
# Evaluating on data sample 1 13th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008761
# Step: 200, Test MSE: 0.007405
# Step: 300, Test MSE: 0.006991
# Step: 400, Test MSE: 0.008436
# Step: 500, Test MSE: 0.007598
# Step: 600, Test MSE: 0.006585
# Step: 700, Test MSE: 0.007030
# Step: 800, Test MSE: 0.007473
# Step: 900, Test MSE: 0.006959
# Step: 1000, Test MSE: 0.006815
# MSE (original scale): 292.7189343310743
# MSE (transformed scale): 0.006815371569246054
# Compression Ratio: 22.721758502896183
# Training time: 10.574222803115845
#
# Evaluating on data sample 1 14th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009802
# Step: 200, Test MSE: 0.007648
# Step: 300, Test MSE: 0.007296
# Step: 400, Test MSE: 0.006988
# Step: 500, Test MSE: 0.007462
# Step: 600, Test MSE: 0.006996
# Step: 700, Test MSE: 0.007062
# Step: 800, Test MSE: 0.006717
# Step: 900, Test MSE: 0.006722
# Step: 1000, Test MSE: 0.006727
# MSE (original scale): 279.24991371736945
# MSE (transformed scale): 0.006726875901222229
# Compression Ratio: 22.721758502896183
# Training time: 10.592057943344116
#
# Evaluating on data sample 1 15th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009077
# Step: 200, Test MSE: 0.007669
# Step: 300, Test MSE: 0.007342
# Step: 400, Test MSE: 0.007051
# Step: 500, Test MSE: 0.006745
# Step: 600, Test MSE: 0.006944
# Step: 700, Test MSE: 0.006753
# Step: 800, Test MSE: 0.006854
# Step: 900, Test MSE: 0.007754
# Step: 1000, Test MSE: 0.007115
# MSE (original scale): 315.4696938796854
# MSE (transformed scale): 0.007115123327821493
# Compression Ratio: 22.721758502896183
# Training time: 10.579086542129517
#
# Evaluating on data sample 1 16th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008735
# Step: 200, Test MSE: 0.007220
# Step: 300, Test MSE: 0.006813
# Step: 400, Test MSE: 0.006663
# Step: 500, Test MSE: 0.006634
# Step: 600, Test MSE: 0.006633
# Step: 700, Test MSE: 0.006483
# Step: 800, Test MSE: 0.006384
# Step: 900, Test MSE: 0.006349
# Step: 1000, Test MSE: 0.006563
# MSE (original scale): 285.66117856844045
# MSE (transformed scale): 0.006562723312526941
# Compression Ratio: 22.721758502896183
# Training time: 10.578097105026245
#
# Evaluating on data sample 1 17th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008362
# Step: 200, Test MSE: 0.007152
# Step: 300, Test MSE: 0.007488
# Step: 400, Test MSE: 0.006999
# Step: 500, Test MSE: 0.006920
# Step: 600, Test MSE: 0.006760
# Step: 700, Test MSE: 0.006328
# Step: 800, Test MSE: 0.006586
# Step: 900, Test MSE: 0.006823
# Step: 1000, Test MSE: 0.006453
# MSE (original scale): 271.2484756735274
# MSE (transformed scale): 0.006453109905123711
# Compression Ratio: 22.721758502896183
# Training time: 10.572129011154175
#
# Evaluating on data sample 1 18th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008807
# Step: 200, Test MSE: 0.007987
# Step: 300, Test MSE: 0.007891
# Step: 400, Test MSE: 0.007815
# Step: 500, Test MSE: 0.007049
# Step: 600, Test MSE: 0.007456
# Step: 700, Test MSE: 0.007147
# Step: 800, Test MSE: 0.006980
# Step: 900, Test MSE: 0.007980
# Step: 1000, Test MSE: 0.006975
# MSE (original scale): 298.5175362909973
# MSE (transformed scale): 0.0069752647541463375
# Compression Ratio: 22.721758502896183
# Training time: 10.617672204971313
#
# Evaluating on data sample 1 19th time: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   sample_fraction: 1
#   max_iters: 1000
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008776
# Step: 200, Test MSE: 0.007369
# Step: 300, Test MSE: 0.007142
# Step: 400, Test MSE: 0.006772
# Step: 500, Test MSE: 0.006953
# Step: 600, Test MSE: 0.006364
# Step: 700, Test MSE: 0.006381
# Step: 800, Test MSE: 0.006385
# Step: 900, Test MSE: 0.006345
# Step: 1000, Test MSE: 0.007270
# MSE (original scale): 315.647960330907
# MSE (transformed scale): 0.007270379923284054
# Compression Ratio: 22.721758502896183
# Training time: 10.582308769226074
#      model  data_sample                                          file_name  \
# 0    SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 1    SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 2    SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 3    SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 4    SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# ..     ...          ...                                                ...
# 195  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 196  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 197  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 198  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
# 199  SIREN            1  outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.x...
#
#      original_mse  compression_ratio  transformed_mse  training_time     lr  \
# 0      380.203287          22.721759         0.008419       2.267893  0.001
# 1      389.925936          22.721759         0.008698       1.809712  0.001
# 2      371.420109          22.721759         0.008334       1.794275  0.001
# 3      388.194048          22.721759         0.008556       1.816535  0.001
# 4      370.095189          22.721759         0.008046       1.809291  0.001
# ..            ...                ...              ...            ...    ...
# 195    315.469694          22.721759         0.007115      10.579087  0.001
# 196    285.661179          22.721759         0.006563      10.578097  0.001
# 197    271.248476          22.721759         0.006453      10.572129  0.001
# 198    298.517536          22.721759         0.006975      10.617672  0.001
# 199    315.647960          22.721759         0.007270      10.582309  0.001
#
#      in_features  hidden_features  hidden_layers  out_features device  \
# 0              3              128              3             1   cuda
# 1              3              128              3             1   cuda
# 2              3              128              3             1   cuda
# 3              3              128              3             1   cuda
# 4              3              128              3             1   cuda
# ..           ...              ...            ...           ...    ...
# 195            3              128              3             1   cuda
# 196            3              128              3             1   cuda
# 197            3              128              3             1   cuda
# 198            3              128              3             1   cuda
# 199            3              128              3             1   cuda
#
#      sample_fraction  max_iters  outermost_linear  first_omega_zero  \
# 0                0.1       1000              True               100
# 1                0.1       1000              True               100
# 2                0.1       1000              True               100
# 3                0.1       1000              True               100
# 4                0.1       1000              True               100
# ..               ...        ...               ...               ...
# 195              1.0       1000              True               100
# 196              1.0       1000              True               100
# 197              1.0       1000              True               100
# 198              1.0       1000              True               100
# 199              1.0       1000              True               100
#
#      hidden_omega_zero
# 0                   45
# 1                   45
# 2                   45
# 3                   45
# 4                   45
# ..                 ...
# 195                 45
# 196                 45
# 197                 45
# 198                 45
# 199                 45
#
# [200 rows x 18 columns]
