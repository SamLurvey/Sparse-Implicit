# %%
import testing

# %%
testing.hyperparameter_grid_search()
# Out:
# Total files found: 31440
#
# Evaluating on data sample 1: outer/12-2_9-1/AuAu200_170kHz_10C_Iter2_3165.xml_TPCMLDataInterface_2.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   outermost_linear: True
# Step: 100, Test MSE: 0.004198
# Step: 200, Test MSE: 0.002669
# Step: 300, Test MSE: 0.002271
# Step: 400, Test MSE: 0.002264
# Step: 500, Test MSE: 0.002599
# Step: 600, Test MSE: 0.002317
# Step: 700, Test MSE: 0.002058
# Step: 800, Test MSE: 0.002109
# Step: 900, Test MSE: 0.002117
# Step: 1000, Test MSE: 0.001873
# MSE (original scale): 3939.614013671875
# MSE (transformed scale): 0.0018733399920165539
# Compression Ratio: 3.8504960811851583
#
# Evaluating on data sample 2: outer/12-2_2-0/AuAu200_170kHz_10C_Iter2_3142.xml_TPCMLDataInterface_8.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
# ...
