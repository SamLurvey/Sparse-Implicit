# %%
from importlib import reload
import torch

import testing_sparse

from models.ffnet import FFNet
from models.mlp import MLP
from models.siren import SIREN
from models.ffnet2 import FFNet2
from models.mfn import GaborNetwork
from models.gaussian import Gaussian
from models.mixed import AlternatingModel

# %%
reload(testing_sparse)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [256],
    'hidden_layers': [4],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [2000],
    'zero_fraction': [0.1],
    'refresh_interval': [100]
    
}
#normal testing
#testing with only some nonzero values
#testing with nonzero values picked each number of steps

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True, False]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.014296
# Step: 200, Test MSE: 0.012271
# Step: 300, Test MSE: 0.012872
# Step: 400, Test MSE: 0.011862
# Step: 500, Test MSE: 0.011974
# Step: 600, Test MSE: 0.014444
# Step: 700, Test MSE: 0.013267
# Step: 800, Test MSE: 0.012642
# Step: 900, Test MSE: 0.011985
# Step: 1000, Test MSE: 0.012353
# Step: 1100, Test MSE: 0.013199
# Step: 1200, Test MSE: 0.012062
# Step: 1300, Test MSE: 0.012260
# Step: 1400, Test MSE: 0.011411
# Step: 1500, Test MSE: 0.011872
# Step: 1600, Test MSE: 0.012245
# Step: 1700, Test MSE: 0.011940
# Step: 1800, Test MSE: 0.012533
# Step: 1900, Test MSE: 0.012528
# Step: 2000, Test MSE: 0.012107
# MSE (original scale): 486.8884051832329
# MSE (transformed scale): 0.012106557376682758
# Compression Ratio: 3.8504960811851583
# Training time: 15.430147409439087
#
# Evaluating on data sample 2: outer/12-2_1-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.015418
# Step: 200, Test MSE: 0.013917
# Step: 300, Test MSE: 0.014085
# Step: 400, Test MSE: 0.013698
# Step: 500, Test MSE: 0.015652
# Step: 600, Test MSE: 0.013712
# Step: 700, Test MSE: 0.013828
# Step: 800, Test MSE: 0.014868
# Step: 900, Test MSE: 0.014911
# Step: 1000, Test MSE: 0.014844
# Step: 1100, Test MSE: 0.014430
# Step: 1200, Test MSE: 0.014217
# Step: 1300, Test MSE: 0.014036
# Step: 1400, Test MSE: 0.013670
# Step: 1500, Test MSE: 0.014189
# Step: 1600, Test MSE: 0.014026
# Step: 1700, Test MSE: 0.017102
# Step: 1800, Test MSE: 0.013390
# Step: 1900, Test MSE: 0.013768
# Step: 2000, Test MSE: 0.015181
# MSE (original scale): 674.2925778635375
# MSE (transformed scale): 0.01518090907484293
# Compression Ratio: 3.8504960811851583
# Training time: 15.996195793151855
#
# Evaluating on data sample 3: outer/12-2_2-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.013262
# Step: 200, Test MSE: 0.015095
# Step: 300, Test MSE: 0.012680
# Step: 400, Test MSE: 0.013557
# Step: 500, Test MSE: 0.012483
# Step: 600, Test MSE: 0.012446
# Step: 700, Test MSE: 0.018128
# Step: 800, Test MSE: 0.012737
# Step: 900, Test MSE: 0.012616
# Step: 1000, Test MSE: 0.012895
# Step: 1100, Test MSE: 0.013784
# Step: 1200, Test MSE: 0.014204
# Step: 1300, Test MSE: 0.012741
# Step: 1400, Test MSE: 0.012853
# Step: 1500, Test MSE: 0.013335
# Step: 1600, Test MSE: 0.013584
# Step: 1700, Test MSE: 0.013649
# Step: 1800, Test MSE: 0.013718
# Step: 1900, Test MSE: 0.012205
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 24
#       3 base_grid = {
#       4     'lr': [1e-3],
#       5     'in_features': [3],
#    (...)
#      11     'zero_fraction': [0.1]
#      12 }
#      14 model_grids = {
#      15     #MLP: base_grid.copy()
#      16     #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]},
#    (...)
#      21     #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
#      22 }
# ---> 24 testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:96, in hyperparameter_grid_search(base_grid, model_grids)
#      92     hyperparameter_combinations = [dict(zip(grid.keys(), values))
#      93                                    for values in itertools.product(*grid.values())]
#      95     for hyperparameters in hyperparameter_combinations:
# ---> 96         results = evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, [ModelClass])
#      97         all_results.extend(results)
#      99 # Convert results to DataFrame
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:59, in evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, model_classes)
#      56 for key, value in hyperparameters.items():
#      57     print(f"  {key}: {value}")
# ---> 59 mse_original, mse_transformed, compression_ratio, training_time = evaluate_model(model, original_data, transformed_data, hyperparameters["max_iters"], hyperparameters["zero_fraction"])
#      61 print(f"MSE (original scale): {mse_original}")
#      62 print(f"MSE (transformed scale): {mse_transformed}")
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:16, in evaluate_model(model, original_data, transformed_data, max_iters, zero_fraction)
#      13 start_time = time.time()
#      15 # Train the model on transformed data
# ---> 16 mse_transformed = model.train_sparse_step(transformed_data, total_steps=max_iters, zero_fraction=zero_fraction)
#      18 training_time = time.time() - start_time
#      20 # Test the model on the same data
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/models/siren.py:123, in SIREN.train_sparse(self, data, total_steps, summary_interval, zero_fraction)
#     121             prediction = self.model(test_coords)
#     122             test_loss = torch.nn.functional.mse_loss(prediction, test_values)
# --> 123             print(f"Step: {step}, Test MSE: {test_loss.item():.6f}")
#     125 return test_loss.item()
#
# KeyboardInterrupt:

# %%
reload(testing_sparse)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [256],
    'hidden_layers': [4],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [2000],
    'zero_fraction': [0.1]
}

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True, False]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.009860
# Step: 200, Test MSE: 0.008292
# Step: 300, Test MSE: 0.007873
# Step: 400, Test MSE: 0.008631
# Step: 500, Test MSE: 0.007151
# Step: 600, Test MSE: 0.006664
# Step: 700, Test MSE: 0.007231
# Step: 800, Test MSE: 0.006569
# Step: 900, Test MSE: 0.008577
# Step: 1000, Test MSE: 0.006402
# Step: 1100, Test MSE: 0.005830
# Step: 1200, Test MSE: 0.006160
# Step: 1300, Test MSE: 0.005941
# Step: 1400, Test MSE: 0.006089
# Step: 1500, Test MSE: 0.006662
# Step: 1600, Test MSE: 0.011359
# Step: 1700, Test MSE: 0.006115
# Step: 1800, Test MSE: 0.005852
# Step: 1900, Test MSE: 0.006272
# Step: 2000, Test MSE: 0.005765
# MSE (original scale): 299.3456299154953
# MSE (transformed scale): 0.005765070207417011
# Compression Ratio: 3.8504960811851583
# Training time: 34.263115644454956
#
# Evaluating on data sample 2: outer/12-2_1-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.013991
# Step: 200, Test MSE: 0.010191
# Step: 300, Test MSE: 0.008938
# Step: 400, Test MSE: 0.008270
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#       3 base_grid = {
#       4     'lr': [1e-3],
#       5     'in_features': [3],
#    (...)
#      11     'zero_fraction': [0.1]
#      12 }
#      14 model_grids = {
#      15     #MLP: base_grid.copy()
#      16     #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]},
#    (...)
#      21     #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
#      22 }
# ---> 24 testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:96, in hyperparameter_grid_search(base_grid, model_grids)
#      92     hyperparameter_combinations = [dict(zip(grid.keys(), values))
#      93                                    for values in itertools.product(*grid.values())]
#      95     for hyperparameters in hyperparameter_combinations:
# ---> 96         results = evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, [ModelClass])
#      97         all_results.extend(results)
#      99 # Convert results to DataFrame
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:59, in evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, model_classes)
#      56 for key, value in hyperparameters.items():
#      57     print(f"  {key}: {value}")
# ---> 59 mse_original, mse_transformed, compression_ratio, training_time = evaluate_model(model, original_data, transformed_data, hyperparameters["max_iters"], hyperparameters["zero_fraction"])
#      61 print(f"MSE (original scale): {mse_original}")
#      62 print(f"MSE (transformed scale): {mse_transformed}")
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:16, in evaluate_model(model, original_data, transformed_data, max_iters, zero_fraction)
#      13 start_time = time.time()
#      15 # Train the model on transformed data
# ---> 16 mse_transformed = model.train_sparse_step(transformed_data, total_steps=max_iters, zero_fraction=zero_fraction)
#      18 training_time = time.time() - start_time
#      20 # Test the model on the same data
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/models/siren.py:143, in SIREN.train_sparse_step(self, data, total_steps, summary_interval, zero_fraction)
#     140 for step in range(1, total_steps + 1):
#     141     # Sample a specified percentage of zero values for each step
#     142     num_zeros_to_sample = int(len(zero_indices) * zero_fraction)
# --> 143     sampled_zero_indices = np.random.choice(zero_indices.cpu().numpy(), num_zeros_to_sample, replace=False)
#     145     # Combine non-zero and sampled zero indices
#     146     sampled_indices = torch.cat([non_zero_indices, torch.tensor(sampled_zero_indices, device=self.device)])
#
# KeyboardInterrupt:

# %%
reload(testing_sparse)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [256],
    'hidden_layers': [4],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [2000],
    'zero_fraction': [0.1]
}

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True, False]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.014297
# Step: 200, Test MSE: 0.011746
# Step: 300, Test MSE: 0.010809
# Step: 400, Test MSE: 0.011237
# Step: 500, Test MSE: 0.010678
# Step: 600, Test MSE: 0.010230
# Step: 700, Test MSE: 0.009841
# Step: 800, Test MSE: 0.010633
# Step: 900, Test MSE: 0.010596
# Step: 1000, Test MSE: 0.010838
# Step: 1100, Test MSE: 0.010163
# Step: 1200, Test MSE: 0.009744
# Step: 1300, Test MSE: 0.010306
# Step: 1400, Test MSE: 0.009769
# Step: 1500, Test MSE: 0.009678
# Step: 1600, Test MSE: 0.010580
# Step: 1700, Test MSE: 0.009633
# Step: 1800, Test MSE: 0.010092
# Step: 1900, Test MSE: 0.010933
# Step: 2000, Test MSE: 0.009575
# MSE (original scale): 366.8507192833835
# MSE (transformed scale): 0.009575128555297852
# Compression Ratio: 3.8504960811851583
# Training time: 15.63550329208374
#
# Evaluating on data sample 2: outer/12-2_1-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 0.1
#   outermost_linear: True
# Step: 100, Test MSE: 0.015201
# Step: 200, Test MSE: 0.013789
# Step: 300, Test MSE: 0.011620
# Step: 400, Test MSE: 0.014001
# Step: 500, Test MSE: 0.011904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 24
#       3 base_grid = {
#       4     'lr': [1e-3],
#       5     'in_features': [3],
#    (...)
#      11     'zero_fraction': [0.1]
#      12 }
#      14 model_grids = {
#      15     #MLP: base_grid.copy()
#      16     #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]},
#    (...)
#      21     #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
#      22 }
# ---> 24 testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:96, in hyperparameter_grid_search(base_grid, model_grids)
#      92     hyperparameter_combinations = [dict(zip(grid.keys(), values))
#      93                                    for values in itertools.product(*grid.values())]
#      95     for hyperparameters in hyperparameter_combinations:
# ---> 96         results = evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, [ModelClass])
#      97         all_results.extend(results)
#      99 # Convert results to DataFrame
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:59, in evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, model_classes)
#      56 for key, value in hyperparameters.items():
#      57     print(f"  {key}: {value}")
# ---> 59 mse_original, mse_transformed, compression_ratio, training_time = evaluate_model(model, original_data, transformed_data, hyperparameters["max_iters"], hyperparameters["zero_fraction"])
#      61 print(f"MSE (original scale): {mse_original}")
#      62 print(f"MSE (transformed scale): {mse_transformed}")
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:16, in evaluate_model(model, original_data, transformed_data, max_iters, zero_fraction)
#      13 start_time = time.time()
#      15 # Train the model on transformed data
# ---> 16 mse_transformed = model.train_sparse_epoch(transformed_data, total_steps=max_iters, zero_fraction=zero_fraction)
#      18 training_time = time.time() - start_time
#      20 # Test the model on the same data
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/models/siren.py:201, in SIREN.train_sparse_epoch(self, data, total_steps, summary_interval, zero_fraction, refresh_interval)
#     199 output = self.model(current_train_coords)
#     200 train_loss = torch.nn.functional.mse_loss(output, current_train_values)
# --> 201 train_loss.backward()
#     202 optim.step()
#     204 if not step % summary_interval:
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
reload(testing_sparse)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [256],
    'hidden_layers': [4],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [2000],
    'zero_fraction': [1],
    'refresh_interval': [2000]
    
}
#normal testing
#testing with only some nonzero values
#testing with nonzero values picked each number of steps

model_grids = {
    #MLP: base_grid.copy()
    #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}, 
    #FFNet: {**base_grid, 'fourier_features': [32, 64], 'scale': [10, 20]}
    SIREN: {**base_grid, 'outermost_linear': [True, False]}
    #GaborNetwork: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0], 'alpha': [1.0, 6.0], 'beta': [1.0, 6.0]}
    #Gaussian: {**base_grid, 'outermost_linear': [True, False]}
    #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
}

testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1: outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 1
#   refresh_interval: 2000
#   outermost_linear: True
# Step: 100, Test MSE: 0.006968
# Step: 200, Test MSE: 0.003740
# Step: 300, Test MSE: 0.003526
# Step: 400, Test MSE: 0.004538
# Step: 500, Test MSE: 0.003061
# Step: 600, Test MSE: 0.002671
# Step: 700, Test MSE: 0.002884
# Step: 800, Test MSE: 0.003692
# Step: 900, Test MSE: 0.003457
# Step: 1000, Test MSE: 0.003730
# Step: 1100, Test MSE: 0.002868
# Step: 1200, Test MSE: 0.003040
# Step: 1300, Test MSE: 0.003233
# Step: 1400, Test MSE: 0.002824
# Step: 1500, Test MSE: 0.002546
# Step: 1600, Test MSE: 0.003016
# Step: 1700, Test MSE: 0.002596
# Step: 1800, Test MSE: 0.002778
# Step: 1900, Test MSE: 0.003265
# Step: 2000, Test MSE: 0.003005
# MSE (original scale): 161.97626443273091
# MSE (transformed scale): 0.0030047865584492683
# Compression Ratio: 3.8504960811851583
# Training time: 68.41871523857117
#
# Evaluating on data sample 2: outer/12-2_1-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 256
#   hidden_layers: 4
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   zero_fraction: 1
#   refresh_interval: 2000
#   outermost_linear: True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 29
#      15 #normal testing
#      16 #testing with only some nonzero values
#      17 #testing with nonzero values picked each number of steps
#      19 model_grids = {
#      20     #MLP: base_grid.copy()
#      21     #FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]},
#    (...)
#      26     #AlternatingModel: {**base_grid, 'outermost_linear': [True, False]}
#      27 }
# ---> 29 testing_sparse.hyperparameter_grid_search(base_grid, model_grids)
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:96, in hyperparameter_grid_search(base_grid, model_grids)
#      92     hyperparameter_combinations = [dict(zip(grid.keys(), values))
#      93                                    for values in itertools.product(*grid.values())]
#      95     for hyperparameters in hyperparameter_combinations:
# ---> 96         results = evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, [ModelClass])
#      97         all_results.extend(results)
#      99 # Convert results to DataFrame
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:59, in evaluate_models(hyperparameters, original_samples, transformed_samples, file_names, model_classes)
#      56 for key, value in hyperparameters.items():
#      57     print(f"  {key}: {value}")
# ---> 59 mse_original, mse_transformed, compression_ratio, training_time = evaluate_model(model, original_data, transformed_data, hyperparameters["max_iters"], hyperparameters["zero_fraction"], hyperparameters["refresh_interval"])
#      61 print(f"MSE (original scale): {mse_original}")
#      62 print(f"MSE (transformed scale): {mse_transformed}")
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/testing_sparse.py:16, in evaluate_model(model, original_data, transformed_data, max_iters, zero_fraction, refresh_interval)
#      13 start_time = time.time()
#      15 # Train the model on transformed data
# ---> 16 mse_transformed = model.train_sparse_epoch(transformed_data, total_steps=max_iters, zero_fraction=zero_fraction, refresh_interval=refresh_interval)
#      18 training_time = time.time() - start_time
#      20 # Test the model on the same data
#
# File ~/workspace/Storage/slurvey/persistent/implicit_sparse_nets/models/siren.py:209, in SIREN.train_sparse_epoch(self, data, total_steps, summary_interval, zero_fraction, refresh_interval)
#     207             prediction = self.model(test_coords)
#     208             test_loss = torch.nn.functional.mse_loss(prediction, test_values)
# --> 209             print(f"Step: {step}, Test MSE: {test_loss.item():.6f}")
#     211 return test_loss.item()
#
# KeyboardInterrupt:
