# %%
pip install scienceplots
# Out:
# Requirement already satisfied: scienceplots in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: matplotlib in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from scienceplots) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from matplotlib->scienceplots) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->scienceplots) (3.11.0)
# Requirement already satisfied: six>=1.5 in /home/idies/miniconda3/envs/py39/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->scienceplots) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from importlib import reload
import torch
import matplotlib.pyplot as plt
import testing_grids
import pandas as pd
import scienceplots
import numpy as np
plt.style.use(['science','no-latex'])

from siren import SIREN
from ffnet2 import FFNet2
from wire import WIRE

# %%
def plot_data(arr1, arr2):
    # Create the figure
    fig = plt.figure(figsize=(24, 8))  # Adjusted width to accommodate two plots

    # Create first subplot for the first array
    ax1 = fig.add_subplot(121, projection='3d')  # 121 means 1 row, 2 columns, first subplot

    # Create meshgrid for plotting
    x1, y1 = np.meshgrid(np.arange(arr1.shape[1]), np.arange(arr1.shape[0]))

    # Plot each layer for the first array
    for i in range(arr1.shape[2]):
        z1 = i * np.ones_like(x1)
        c1 = arr1[:,:,i]
        ax1.plot_surface(x1, y1, z1, facecolors=plt.cm.Reds(np.abs(c1)), 
                        rstride=1, cstride=1, alpha=0.3, shade=False)

    # Set labels and title for the first subplot
    ax1.set_xlabel('azimuthal')
    ax1.set_ylabel('z')
    ax1.set_zlabel('layer')
    ax1.set_title('3D Heatmap of sin(x) Array - Dataset 1')

    # Set axis limits for the first subplot
    ax1.set_xlim(0, arr1.shape[1])
    ax1.set_ylim(0, arr1.shape[0])
    ax1.set_zlim(0, arr1.shape[2])

    # Adjust the view angle for the first subplot
    ax1.view_init(elev=20, azim=-45)

    # Create second subplot for the second array
    ax2 = fig.add_subplot(122, projection='3d')  # 122 means 1 row, 2 columns, second subplot

    # Create meshgrid for plotting
    x2, y2 = np.meshgrid(np.arange(arr2.shape[1]), np.arange(arr2.shape[0]))

    # Plot each layer for the second array
    for i in range(arr2.shape[2]):
        z2 = i * np.ones_like(x2)
        c2 = arr2[:,:,i]
        ax2.plot_surface(x2, y2, z2, facecolors=plt.cm.Reds(np.abs(c2)), 
                        rstride=1, cstride=1, alpha=0.3, shade=False)

    # Set labels and title for the second subplot
    ax2.set_xlabel('azimuthal')
    ax2.set_ylabel('z')
    ax2.set_zlabel('layer')
    ax2.set_title('3D Heatmap of sin(x) Array - Dataset 2')

    # Set axis limits for the second subplot
    ax2.set_xlim(0, arr2.shape[1])
    ax2.set_ylim(0, arr2.shape[0])
    ax2.set_zlim(0, arr2.shape[2])

    # Adjust the view angle for the second subplot
    ax2.view_init(elev=20, azim=-45)

    plt.show()

# %%
path = "../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_0.npy"

smaller_grids = {
    'grid_c': (192, 125, 16),
    'grid_d': (192, 249, 8),
    'grid_e': (96, 125, 16),
    'grid_f': (96, 125, 8)
}

# %%
reload(testing_grids)

base_grid = {
    'lr': [1e-3],
    'in_features': [3],
    'hidden_features': [128],
    'hidden_layers': [3],
    'out_features': [1],
    'device': ['cuda' if torch.cuda.is_available() else 'cpu'],
    'max_iters': [2000],
    'grid_size': [(192,249,16),(192, 125, 16),(192,249,8),(96,125,16),(96,125,8)]
}

model_grids = {
    SIREN: {**base_grid, 'outermost_linear': [True],'first_omega_zero':[100],'hidden_omega_zero':[45]},
    WIRE: {**base_grid, 'a':[50], 's':[30]},
    FFNet2: {**base_grid, 'input_scale': [256.0], 'weight_scale': [1.0]}
}

testing_grids.hyperparameter_grid_search(base_grid, model_grids)
# Out:
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 16)
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.009589
# Step: 200, Test MSE: 0.007931
# Step: 300, Test MSE: 0.007520
# Step: 400, Test MSE: 0.007342
# Step: 500, Test MSE: 0.007254
# Step: 600, Test MSE: 0.007444
# Step: 700, Test MSE: 0.007383
# Step: 800, Test MSE: 0.007432
# Step: 900, Test MSE: 0.007083
# Step: 1000, Test MSE: 0.007129
# Step: 1100, Test MSE: 0.007037
# Step: 1200, Test MSE: 0.007253
# Step: 1300, Test MSE: 0.007099
# Step: 1400, Test MSE: 0.007063
# Step: 1500, Test MSE: 0.007301
# Step: 1600, Test MSE: 0.007317
# Step: 1700, Test MSE: 0.007126
# Step: 1800, Test MSE: 0.007280
# Step: 1900, Test MSE: 0.007335
# Step: 2000, Test MSE: 0.007315
# MSE (original scale): 439.4382700071118
# MSE (transformed scale): 0.007315305061638355
# Compression Ratio: 22.721758502896183
# Training time: 20.235655784606934
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 125, 16)
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.005446
# Step: 200, Test MSE: 0.003941
# Step: 300, Test MSE: 0.003670
# Step: 400, Test MSE: 0.003595
# Step: 500, Test MSE: 0.003523
# Step: 600, Test MSE: 0.003464
# Step: 700, Test MSE: 0.003234
# Step: 800, Test MSE: 0.003237
# Step: 900, Test MSE: 0.003174
# Step: 1000, Test MSE: 0.003174
# Step: 1100, Test MSE: 0.003455
# Step: 1200, Test MSE: 0.003349
# Step: 1300, Test MSE: 0.003015
# Step: 1400, Test MSE: 0.003011
# Step: 1500, Test MSE: 0.002978
# Step: 1600, Test MSE: 0.002977
# Step: 1700, Test MSE: 0.003133
# Step: 1800, Test MSE: 0.002883
# Step: 1900, Test MSE: 0.003043
# Step: 2000, Test MSE: 0.002859
# MSE (original scale): 287.58454782672356
# MSE (transformed scale): 0.0028588578570634127
# Compression Ratio: 22.721758502896183
# Training time: 11.047096967697144
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 8)
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.004783
# Step: 200, Test MSE: 0.003780
# Step: 300, Test MSE: 0.003451
# Step: 400, Test MSE: 0.003324
# Step: 500, Test MSE: 0.003173
# Step: 600, Test MSE: 0.003143
# Step: 700, Test MSE: 0.003118
# Step: 800, Test MSE: 0.003023
# Step: 900, Test MSE: 0.003075
# Step: 1000, Test MSE: 0.003004
# Step: 1100, Test MSE: 0.003076
# Step: 1200, Test MSE: 0.003083
# Step: 1300, Test MSE: 0.002983
# Step: 1400, Test MSE: 0.003057
# Step: 1500, Test MSE: 0.003083
# Step: 1600, Test MSE: 0.003016
# Step: 1700, Test MSE: 0.002976
# Step: 1800, Test MSE: 0.002921
# Step: 1900, Test MSE: 0.002979
# Step: 2000, Test MSE: 0.003025
# MSE (original scale): 1999.4480826953647
# MSE (transformed scale): 0.0030249834526330233
# Compression Ratio: 22.721758502896183
# Training time: 11.012628555297852
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 16)
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.008002
# Step: 200, Test MSE: 0.006766
# Step: 300, Test MSE: 0.006300
# Step: 400, Test MSE: 0.006126
# Step: 500, Test MSE: 0.006077
# Step: 600, Test MSE: 0.006811
# Step: 700, Test MSE: 0.006030
# Step: 800, Test MSE: 0.006095
# Step: 900, Test MSE: 0.005878
# Step: 1000, Test MSE: 0.005904
# Step: 1100, Test MSE: 0.006260
# Step: 1200, Test MSE: 0.006063
# Step: 1300, Test MSE: 0.005904
# Step: 1400, Test MSE: 0.005930
# Step: 1500, Test MSE: 0.006165
# Step: 1600, Test MSE: 0.005930
# Step: 1700, Test MSE: 0.005911
# Step: 1800, Test MSE: 0.006104
# Step: 1900, Test MSE: 0.006050
# Step: 2000, Test MSE: 0.005898
# MSE (original scale): 526.4388426100235
# MSE (transformed scale): 0.005898187402635813
# Compression Ratio: 22.721758502896183
# Training time: 6.239707708358765
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating SIREN
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 8)
#   outermost_linear: True
#   first_omega_zero: 100
#   hidden_omega_zero: 45
# Step: 100, Test MSE: 0.002254
# Step: 200, Test MSE: 0.001568
# Step: 300, Test MSE: 0.001118
# Step: 400, Test MSE: 0.001050
# Step: 500, Test MSE: 0.000988
# Step: 600, Test MSE: 0.000879
# Step: 700, Test MSE: 0.000947
# Step: 800, Test MSE: 0.000858
# Step: 900, Test MSE: 0.001211
# Step: 1000, Test MSE: 0.000853
# Step: 1100, Test MSE: 0.000932
# Step: 1200, Test MSE: 0.000834
# Step: 1300, Test MSE: 0.000824
# Step: 1400, Test MSE: 0.000784
# Step: 1500, Test MSE: 0.000933
# Step: 1600, Test MSE: 0.000837
# Step: 1700, Test MSE: 0.000797
# Step: 1800, Test MSE: 0.000862
# Step: 1900, Test MSE: 0.000789
# Step: 2000, Test MSE: 0.000900
# MSE (original scale): 2077.5993570636715
# MSE (transformed scale): 0.0008998406701721251
# Compression Ratio: 22.721758502896183
# Training time: 3.3900439739227295
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating WIRE
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 16)
#   a: 50
#   s: 30
# Step: 100, Test MSE: 0.016468
# Step: 200, Test MSE: 0.011994
# Step: 300, Test MSE: 0.010278
# Step: 400, Test MSE: 0.009660
# Step: 500, Test MSE: 0.008866
# Step: 600, Test MSE: 0.008369
# Step: 700, Test MSE: 0.008116
# Step: 800, Test MSE: 0.007997
# Step: 900, Test MSE: 0.007783
# Step: 1000, Test MSE: 0.007621
# Step: 1100, Test MSE: 0.007668
# Step: 1200, Test MSE: 0.007492
# Step: 1300, Test MSE: 0.007412
# Step: 1400, Test MSE: 0.007336
# Step: 1500, Test MSE: 0.007343
# Step: 1600, Test MSE: 0.007401
# Step: 1700, Test MSE: 0.007253
# Step: 1800, Test MSE: 0.007291
# Step: 1900, Test MSE: 0.007267
# Step: 2000, Test MSE: 0.007126
# MSE (original scale): 361.25476253974233
# MSE (transformed scale): 0.007125552278012037
# Compression Ratio: 22.721758502896183
# Training time: 46.81324553489685
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating WIRE
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 125, 16)
#   a: 50
#   s: 30
# Step: 100, Test MSE: 0.015725
# Step: 200, Test MSE: 0.011520
# Step: 300, Test MSE: 0.009913
# Step: 400, Test MSE: 0.009066
# Step: 500, Test MSE: 0.008426
# Step: 600, Test MSE: 0.007997
# Step: 700, Test MSE: 0.007916
# Step: 800, Test MSE: 0.007565
# Step: 900, Test MSE: 0.007415
# Step: 1000, Test MSE: 0.007365
# Step: 1100, Test MSE: 0.007091
# Step: 1200, Test MSE: 0.007218
# Step: 1300, Test MSE: 0.006848
# Step: 1400, Test MSE: 0.006912
# Step: 1500, Test MSE: 0.006851
# Step: 1600, Test MSE: 0.006826
# Step: 1700, Test MSE: 0.006691
# Step: 1800, Test MSE: 0.006686
# Step: 1900, Test MSE: 0.006769
# Step: 2000, Test MSE: 0.006740
# MSE (original scale): 771.8741410956326
# MSE (transformed scale): 0.006739584729075432
# Compression Ratio: 22.721758502896183
# Training time: 24.550716161727905
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating WIRE
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 8)
#   a: 50
#   s: 30
# Step: 100, Test MSE: 0.013016
# Step: 200, Test MSE: 0.008676
# Step: 300, Test MSE: 0.007419
# Step: 400, Test MSE: 0.006523
# Step: 500, Test MSE: 0.006491
# Step: 600, Test MSE: 0.005754
# Step: 700, Test MSE: 0.005486
# Step: 800, Test MSE: 0.005468
# Step: 900, Test MSE: 0.005384
# Step: 1000, Test MSE: 0.005205
# Step: 1100, Test MSE: 0.005522
# Step: 1200, Test MSE: 0.004984
# Step: 1300, Test MSE: 0.004906
# Step: 1400, Test MSE: 0.004891
# Step: 1500, Test MSE: 0.004883
# Step: 1600, Test MSE: 0.004759
# Step: 1700, Test MSE: 0.004949
# Step: 1800, Test MSE: 0.004777
# Step: 1900, Test MSE: 0.004684
# Step: 2000, Test MSE: 0.004892
# MSE (original scale): 5227.91472530748
# MSE (transformed scale): 0.004892255179584026
# Compression Ratio: 22.721758502896183
# Training time: 24.471949577331543
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating WIRE
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 16)
#   a: 50
#   s: 30
# Step: 100, Test MSE: 0.018319
# Step: 200, Test MSE: 0.012847
# Step: 300, Test MSE: 0.010825
# Step: 400, Test MSE: 0.009674
# Step: 500, Test MSE: 0.009182
# Step: 600, Test MSE: 0.008824
# Step: 700, Test MSE: 0.008572
# Step: 800, Test MSE: 0.008386
# Step: 900, Test MSE: 0.008265
# Step: 1000, Test MSE: 0.008141
# Step: 1100, Test MSE: 0.008232
# Step: 1200, Test MSE: 0.008042
# Step: 1300, Test MSE: 0.008015
# Step: 1400, Test MSE: 0.007987
# Step: 1500, Test MSE: 0.007942
# Step: 1600, Test MSE: 0.008069
# Step: 1700, Test MSE: 0.007908
# Step: 1800, Test MSE: 0.007895
# Step: 1900, Test MSE: 0.007847
# Step: 2000, Test MSE: 0.007805
# MSE (original scale): 673.6154082475737
# MSE (transformed scale): 0.007805272471159697
# Compression Ratio: 22.721758502896183
# Training time: 13.101446866989136
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating WIRE
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 8)
#   a: 50
#   s: 30
# Step: 100, Test MSE: 0.014179
# Step: 200, Test MSE: 0.009072
# Step: 300, Test MSE: 0.007011
# Step: 400, Test MSE: 0.006050
# Step: 500, Test MSE: 0.005145
# Step: 600, Test MSE: 0.004652
# Step: 700, Test MSE: 0.004347
# Step: 800, Test MSE: 0.004111
# Step: 900, Test MSE: 0.003892
# Step: 1000, Test MSE: 0.003881
# Step: 1100, Test MSE: 0.003910
# Step: 1200, Test MSE: 0.003628
# Step: 1300, Test MSE: 0.003648
# Step: 1400, Test MSE: 0.003618
# Step: 1500, Test MSE: 0.003559
# Step: 1600, Test MSE: 0.003651
# Step: 1700, Test MSE: 0.003452
# Step: 1800, Test MSE: 0.003470
# Step: 1900, Test MSE: 0.003382
# Step: 2000, Test MSE: 0.003422
# MSE (original scale): 2543.5976418695614
# MSE (transformed scale): 0.0034224516712129116
# Compression Ratio: 22.721758502896183
# Training time: 7.023045301437378
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating FFNet2
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 16)
#   input_scale: 256.0
#   weight_scale: 1.0
# Step: 100, Test MSE: 0.009715
# Step: 200, Test MSE: 0.007037
# Step: 300, Test MSE: 0.006225
# Step: 400, Test MSE: 0.005823
# Step: 500, Test MSE: 0.005589
# Step: 600, Test MSE: 0.005432
# Step: 700, Test MSE: 0.005319
# Step: 800, Test MSE: 0.005236
# Step: 900, Test MSE: 0.005172
# Step: 1000, Test MSE: 0.005118
# Step: 1100, Test MSE: 0.005075
# Step: 1200, Test MSE: 0.005040
# Step: 1300, Test MSE: 0.005009
# Step: 1400, Test MSE: 0.004983
# Step: 1500, Test MSE: 0.004961
# Step: 1600, Test MSE: 0.004942
# Step: 1700, Test MSE: 0.004925
# Step: 1800, Test MSE: 0.004909
# Step: 1900, Test MSE: 0.004896
# Step: 2000, Test MSE: 0.004885
# MSE (original scale): 281.6547845025937
# MSE (transformed scale): 0.004884560126811266
# Compression Ratio: 14.79179316612844
# Training time: 35.082831382751465
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating FFNet2
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 125, 16)
#   input_scale: 256.0
#   weight_scale: 1.0
# Step: 100, Test MSE: 0.009240
# Step: 200, Test MSE: 0.006684
# Step: 300, Test MSE: 0.005935
# Step: 400, Test MSE: 0.005543
# Step: 500, Test MSE: 0.005311
# Step: 600, Test MSE: 0.005167
# Step: 700, Test MSE: 0.005058
# Step: 800, Test MSE: 0.004970
# Step: 900, Test MSE: 0.004904
# Step: 1000, Test MSE: 0.004857
# Step: 1100, Test MSE: 0.004821
# Step: 1200, Test MSE: 0.004787
# Step: 1300, Test MSE: 0.004756
# Step: 1400, Test MSE: 0.004730
# Step: 1500, Test MSE: 0.004709
# Step: 1600, Test MSE: 0.004689
# Step: 1700, Test MSE: 0.004672
# Step: 1800, Test MSE: 0.004657
# Step: 1900, Test MSE: 0.004644
# Step: 2000, Test MSE: 0.004632
# MSE (original scale): 286.2007430764726
# MSE (transformed scale): 0.004632280208170414
# Compression Ratio: 14.79179316612844
# Training time: 19.545207977294922
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating FFNet2
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (192, 249, 8)
#   input_scale: 256.0
#   weight_scale: 1.0
# Step: 100, Test MSE: 0.006892
# Step: 200, Test MSE: 0.004888
# Step: 300, Test MSE: 0.004295
# Step: 400, Test MSE: 0.004007
# Step: 500, Test MSE: 0.003836
# Step: 600, Test MSE: 0.003717
# Step: 700, Test MSE: 0.003630
# Step: 800, Test MSE: 0.003564
# Step: 900, Test MSE: 0.003511
# Step: 1000, Test MSE: 0.003467
# Step: 1100, Test MSE: 0.003430
# Step: 1200, Test MSE: 0.003398
# Step: 1300, Test MSE: 0.003371
# Step: 1400, Test MSE: 0.003347
# Step: 1500, Test MSE: 0.003326
# Step: 1600, Test MSE: 0.003307
# Step: 1700, Test MSE: 0.003291
# Step: 1800, Test MSE: 0.003276
# Step: 1900, Test MSE: 0.003264
# Step: 2000, Test MSE: 0.003253
# MSE (original scale): 3453563255.531292
# MSE (transformed scale): 0.003252689028158784
# Compression Ratio: 14.79179316612844
# Training time: 19.486666679382324
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating FFNet2
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 16)
#   input_scale: 256.0
#   weight_scale: 1.0
# Step: 100, Test MSE: 0.009022
# Step: 200, Test MSE: 0.006181
# Step: 300, Test MSE: 0.005301
# Step: 400, Test MSE: 0.004877
# Step: 500, Test MSE: 0.004628
# Step: 600, Test MSE: 0.004464
# Step: 700, Test MSE: 0.004347
# Step: 800, Test MSE: 0.004258
# Step: 900, Test MSE: 0.004189
# Step: 1000, Test MSE: 0.004132
# Step: 1100, Test MSE: 0.004083
# Step: 1200, Test MSE: 0.004041
# Step: 1300, Test MSE: 0.004009
# Step: 1400, Test MSE: 0.003982
# Step: 1500, Test MSE: 0.003958
# Step: 1600, Test MSE: 0.003937
# Step: 1700, Test MSE: 0.003919
# Step: 1800, Test MSE: 0.003902
# Step: 1900, Test MSE: 0.003887
# Step: 2000, Test MSE: 0.003873
# MSE (original scale): 403.6214114269578
# MSE (transformed scale): 0.003873168956488371
# Compression Ratio: 14.79179316612844
# Training time: 11.080962419509888
#
# Evaluating on data sample 1: ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_3001.xml_TPCMLDataInterface_1.npy
#
# Evaluating FFNet2
# Hyperparameters:
#   lr: 0.001
#   in_features: 3
#   hidden_features: 128
#   hidden_layers: 3
#   out_features: 1
#   device: cuda
#   max_iters: 2000
#   grid_size: (96, 125, 8)
#   input_scale: 256.0
#   weight_scale: 1.0
# Step: 100, Test MSE: 0.005913
# Step: 200, Test MSE: 0.003771
# Step: 300, Test MSE: 0.003109
# Step: 400, Test MSE: 0.002776
# Step: 500, Test MSE: 0.002569
# Step: 600, Test MSE: 0.002421
# Step: 700, Test MSE: 0.002308
# Step: 800, Test MSE: 0.002221
# Step: 900, Test MSE: 0.002151
# Step: 1000, Test MSE: 0.002092
# Step: 1100, Test MSE: 0.002043
# Step: 1200, Test MSE: 0.002002
# Step: 1300, Test MSE: 0.001968
# Step: 1400, Test MSE: 0.001938
# Step: 1500, Test MSE: 0.001912
# Step: 1600, Test MSE: 0.001890
# Step: 1700, Test MSE: 0.001872
# Step: 1800, Test MSE: 0.001854
# Step: 1900, Test MSE: 0.001841
# Step: 2000, Test MSE: 0.001827
# MSE (original scale): 101735055926.5164
# MSE (transformed scale): 0.0018274526810273528
# Compression Ratio: 14.79179316612844
# Training time: 5.8910157680511475
#      model  data_sample                                          file_name  \
# 0    SIREN            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 1    SIREN            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 2    SIREN            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 3    SIREN            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 4    SIREN            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 5     WIRE            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 6     WIRE            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 7     WIRE            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 8     WIRE            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 9     WIRE            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 10  FFNet2            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 11  FFNet2            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 12  FFNet2            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 13  FFNet2            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
# 14  FFNet2            1  ../outer/12-2_0-0/AuAu200_170kHz_10C_Iter2_300...
#
#     original_mse  compression_ratio  transformed_mse  training_time  \
# 0   4.394383e+02          22.721759         0.007315      20.235656
# 1   2.875845e+02          22.721759         0.002859      11.047097
# 2   1.999448e+03          22.721759         0.003025      11.012629
# 3   5.264388e+02          22.721759         0.005898       6.239708
# 4   2.077599e+03          22.721759         0.000900       3.390044
# 5   3.612548e+02          22.721759         0.007126      46.813246
# 6   7.718741e+02          22.721759         0.006740      24.550716
# 7   5.227915e+03          22.721759         0.004892      24.471950
# 8   6.736154e+02          22.721759         0.007805      13.101447
# 9   2.543598e+03          22.721759         0.003422       7.023045
# 10  2.816548e+02          14.791793         0.004885      35.082831
# 11  2.862007e+02          14.791793         0.004632      19.545208
# 12  3.453563e+09          14.791793         0.003253      19.486667
# 13  4.036214e+02          14.791793         0.003873      11.080962
# 14  1.017351e+11          14.791793         0.001827       5.891016
#
#                                       prediction_path     lr  in_features  \
# 0   saved_predictions/SIREN_sample1_grid(192, 249,...  0.001            3
# 1   saved_predictions/SIREN_sample1_grid(192, 125,...  0.001            3
# 2   saved_predictions/SIREN_sample1_grid(192, 249,...  0.001            3
# 3   saved_predictions/SIREN_sample1_grid(96, 125, ...  0.001            3
# 4   saved_predictions/SIREN_sample1_grid(96, 125, ...  0.001            3
# 5   saved_predictions/WIRE_sample1_grid(192, 249, ...  0.001            3
# 6   saved_predictions/WIRE_sample1_grid(192, 125, ...  0.001            3
# 7   saved_predictions/WIRE_sample1_grid(192, 249, ...  0.001            3
# 8   saved_predictions/WIRE_sample1_grid(96, 125, 1...  0.001            3
# 9   saved_predictions/WIRE_sample1_grid(96, 125, 8...  0.001            3
# 10  saved_predictions/FFNet2_sample1_grid(192, 249...  0.001            3
# 11  saved_predictions/FFNet2_sample1_grid(192, 125...  0.001            3
# 12  saved_predictions/FFNet2_sample1_grid(192, 249...  0.001            3
# 13  saved_predictions/FFNet2_sample1_grid(96, 125,...  0.001            3
# 14  saved_predictions/FFNet2_sample1_grid(96, 125,...  0.001            3
#
#     ...  device  max_iters       grid_size outermost_linear  first_omega_zero  \
# 0   ...    cuda       2000  (192, 249, 16)             True             100.0
# 1   ...    cuda       2000  (192, 125, 16)             True             100.0
# 2   ...    cuda       2000   (192, 249, 8)             True             100.0
# 3   ...    cuda       2000   (96, 125, 16)             True             100.0
# 4   ...    cuda       2000    (96, 125, 8)             True             100.0
# 5   ...    cuda       2000  (192, 249, 16)              NaN               NaN
# 6   ...    cuda       2000  (192, 125, 16)              NaN               NaN
# 7   ...    cuda       2000   (192, 249, 8)              NaN               NaN
# 8   ...    cuda       2000   (96, 125, 16)              NaN               NaN
# 9   ...    cuda       2000    (96, 125, 8)              NaN               NaN
# 10  ...    cuda       2000  (192, 249, 16)              NaN               NaN
# 11  ...    cuda       2000  (192, 125, 16)              NaN               NaN
# 12  ...    cuda       2000   (192, 249, 8)              NaN               NaN
# 13  ...    cuda       2000   (96, 125, 16)              NaN               NaN
# 14  ...    cuda       2000    (96, 125, 8)              NaN               NaN
#
#    hidden_omega_zero     a     s  input_scale  weight_scale
# 0               45.0   NaN   NaN          NaN           NaN
# 1               45.0   NaN   NaN          NaN           NaN
# 2               45.0   NaN   NaN          NaN           NaN
# 3               45.0   NaN   NaN          NaN           NaN
# 4               45.0   NaN   NaN          NaN           NaN
# 5                NaN  50.0  30.0          NaN           NaN
# 6                NaN  50.0  30.0          NaN           NaN
# 7                NaN  50.0  30.0          NaN           NaN
# 8                NaN  50.0  30.0          NaN           NaN
# 9                NaN  50.0  30.0          NaN           NaN
# 10               NaN   NaN   NaN        256.0           1.0
# 11               NaN   NaN   NaN        256.0           1.0
# 12               NaN   NaN   NaN        256.0           1.0
# 13               NaN   NaN   NaN        256.0           1.0
# 14               NaN   NaN   NaN        256.0           1.0
#
# [15 rows x 23 columns]
